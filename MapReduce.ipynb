# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      |▍
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#      |████████████████████████████████| 317.0 MB 7.0 kB/s
# Collecting py4j==0.10.9.7
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 38.7 MB/s
# Building wheels for collected packages: pyspark
# done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488511 sha256=dc496af5c9317ef2765bd022bf7eb8b440bb311b49dfe56aac50efbaff00bbd1
#   Stored in directory: /root/.cache/pip/wheels/92/09/11/aa01d01a7f005fda8a66ad71d2be7f8aa341bddafb27eee3c7
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.7 pyspark-3.5.1
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-e044d9f1-1428-443c-9fb7-278be5aa6745/bin/python -m pip install --upgrade pip' command.

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf

# %%
config = SparkConf()
config.setMaster("local").setAppName("MapReduce")
print(f' Master URL: {config.get("spark.master")}')
print(f' App Name: {config.get("spark.app.name")}')
# Out:
#  Master URL: local
#  App Name: MapReduce

# %%
spk_cntxt = SparkContext.getOrCreate()
spk_cntxt
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=3321560113171825#setting/sparkui/0228-183825-orvded3p/driver-8337963192587264397">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
spark = SparkSession.builder.appName("MapReduce").master("local").getOrCreate()

# %%
 spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=3321560113171825#setting/sparkui/0228-183825-orvded3p/driver-8337963192587264397">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
path = 'dbfs:/FileStore/shared_uploads/202318060@daiict.ac.in/Apple.txt'
rdd = spark.sparkContext.textFile(path) # RDD created

# %%
lines = spk_cntxt.textFile(path)

# %%
rdd.collect()
# Out:
# Out[40]: ['',
#  'Forums',
#  'Search Site...',
#  'Apple Vision ProiOS 17iPhone 15iPhone 15 ProiPhone 16iPhone 16 PromacOS SonomavisionOSwatchOS 10MacBook Pro 14 & 16"HomePodiPhone 14Apple TViPad ProApple Watch Ultra 2iPadAirPods 3Apple CarApple Pro Display XDRHomePod miniMac ProMacBook AiriPhone 13AirPods MaxAirPods ProApple DealsApple Studio DisplayApple Watch SEMac StudioiMaciPad AiriPad miniiPhone SEMac miniiOS 18Apple Watch Series 9CarPlayiPadOS 17Apple Pay',
#  'All >',
#  'MacRumors iPhone and iPad Blog: Apps, News, and Rumors',
#  'Apple News and Rumors',
#  '',
#  'Deals: Adorama Introduces New Low Prices on 32GB Apple TV 4K ($159) and AirPods Max ($449)',
#  'Tuesday October 5, 2021 7:27 am PDT by Mitchel Broussard',
#  'Adorama today has a collection of deals on select Apple products, including the AirPods Max, Apple TV 4K, and M1 MacBook Pro. Note: MacRumors is an affiliate partner with Adorama. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site running. Apple TV 4K You can get the 32GB Apple TV 4K for $159.00, down from $179.00. This is a new all-time ...',
#  'Read Full Article 11 comments',
#  '',
#  'Deals: Get $10 Amazon Credit When Purchasing a $100 Apple Gift Card',
#  'Monday October 4, 2021 8:52 am PDT by Mitchel Broussard',
#  'Amazon today is offering $10 in Amazon credit when you spend $100 or more on the Apple Gift Card. This card is digital and will be delivered to you via email, and the offer will automatically be applied at the checkout screen. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment, which helps us keep the...',
#  'Read Full Article 44 comments',
#  '',
#  'Deals: New Sales Hit Every AirPods Model, Starting at $109 for Regular AirPods',
#  'Monday October 4, 2021 7:49 am PDT by Mitchel Broussard',
#  "Today we're tracking new sales on every model of Apple's AirPods, starting with a return of the lowest-ever price on the AirPods with Wireless Charging Case on Amazon, priced at $129.00, down from $199.00. Below you'll also find sales on the AirPods with Wired Charging Case, AirPods Pro, and AirPods Max. Note: MacRumors is an affiliate partner with these vendors. When you click a link and make ...",
#  'Read Full Article 13 comments',
#  '',
#  'Deals: Take Up To $100 Off 2021 iPad Pro Tablets at Amazon',
#  'Friday October 1, 2021 7:28 am PDT by Mitchel Broussard',
#  "Amazon today has a few deals on the 2021 iPad Pro in both 11-inch and 12.9-inch configurations. You'll have a chance to save up to $100 on these models, and this sale focuses on Wi-Fi only tablets and they're all available on Amazon. Note: MacRumors is an affiliate partner with Amazon. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site...",
#  'Read Full Article 2 comments',
#  '',
#  "Deals: Apple's MagSafe Battery Pack Drops to $84.15 ($15 Off)",
#  'Thursday September 30, 2021 11:22 am PDT by Mitchel Broussard',
#  "Yesterday we shared a new discount event happening at AT&T, where you can get 15 percent off select Apple accessories this fall. One notable accessory in the sale was the MagSafe Battery Pack, but it was out of stock. Today, however, that's changed, and you can now order the MagSafe Battery Pack for $84.15, down from $99.00. Note: MacRumors is an affiliate partner with some of these vendors....",
#  'Read Full Article 19 comments',
#  '',
#  "Deals: Get 20% Off Hyper's 18W Battery Packs and Satechi's 100W USB-C Wall Charger",
#  'Thursday September 30, 2021 8:18 am PDT by Mitchel Broussard',
#  "Today we have a pair of charging-related deals from Hyper and Satechi, which are offering 20 percent off a portable battery and USB-C wall charger, respectively. Hyper's sale will end later today, while Satechi's will run for one week, through October 7. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small...",
#  'Read Full Article 12 comments',
#  '',
#  "Deals: AT&T Taking 15% Off Apple's MagSafe Accessories",
#  'Wednesday September 29, 2021 7:58 am PDT by Mitchel Broussard',
#  "Today at AT&T you can get 15 percent off a wide selection of Apple's MagSafe accessories, including Clear, Silicone, and Leather Cases for the iPhone 13, 13 mini, 13 Pro, and 13 Pro Max. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site running. Sale prices have been...",
#  'Read Full Article 13 comments',
#  '',
#  "Deals: Get Apple's 256GB Wi-Fi iPad Air for $649.99 ($99 Off)",
#  'Tuesday September 28, 2021 10:05 am PDT by Mitchel Broussard',
#  'Amazon today has the 256GB iPad Air for $649.99, down from $749.00. This sale price is available in Rose Gold, Silver, Sky Blue, and Space Gray, but only Rose Gold is available to ship out today. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site running. This same sale...',
#  'Read Full Article 3 comments',
#  '',
#  'Deals: Verizon Offering Up to 30% Off MagSafe Accessory Bundles, iPhone 13 Cases, and More',
#  'Monday September 27, 2021 11:53 am PDT by Mitchel Broussard',
#  "Today we're tracking a handful of solid accessory discounts offered by Verizon, offering a chance to save on a new case or screen protector for your iPhone 13, MagSafe bundles, and more. Verizon offers free two day shipping across the board on orders over $49, even if you don't use Verizon as a carrier. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link...",
#  'Read Full Article 10 comments',
#  '',
#  "Deals: Get Up to 45% Off Anker's USB-C Chargers, MagSafe-Compatible Accessories, and More",
#  'Monday September 27, 2021 8:39 am PDT by Mitchel Broussard',
#  'Anker today introduced a new Gold Box sale on Amazon, taking up to 45 percent off select accessories for one day only. This time around, the deals include savings on USB-C wall chargers, portable batteries, and MagSafe-compatible wireless chargers. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment,...',
#  'Read Full Article 12 comments',
#  '',
#  'Deals: Get a $200 Virtual Gift Card and Free HomePod Mini With Purchase of iPhone 13 at Visible',
#  'Friday September 24, 2021 7:19 am PDT by Mitchel Broussard',
#  "It's iPhone 13 launch day today, and anyone who hasn't pre-ordered the smartphone still has plenty of options to purchase the new iPhone. In this article we're highlighting a deal from Verizon-owned Visible Wireless, which is a low-cost alternative to the big name carriers. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may...",
#  'Read Full Article 12 comments',
#  '',
#  'Deals: Amazon Drops Price of New 64GB Wi-Fi iPad to $299.00 for the First Time ($30 Off)',
#  'Thursday September 23, 2021 9:09 am PDT by Mitchel Broussard',
#  'The first Amazon discount has arrived today for the new 10.2-inch iPad, and you can get the 64GB Wi-Fi model for $299.00, down from $329.00. This price is only available in Space Gray on Amazon. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site running. This sale is...',
#  'Read Full Article 12 comments',
#  '',
#  "Deals: Take 20% Off a Bundle of Satechi's New MagSafe-Compatible and Dual USB-C Car Chargers",
#  'Thursday September 23, 2021 7:00 am PDT by Mitchel Broussard',
#  "Satechi today announced the release of a trio of new accessories, aimed at charging up an iPhone in your car. These devices are available to order today on Satechi's website, and when you bundle two of them you can save 20 percent off your order. Note: MacRumors is an affiliate partner with Satechi. When you click a link and make a purchase, we may receive a small payment, which helps us keep...",
#  'Read Full Article 35 comments',
#  '',
#  "Deals: Record-Low Prices Hit Apple's Latest 12.9-Inch iPad Pro Magic Keyboard, Starting at $324.88 for Black",
#  'Wednesday September 22, 2021 1:15 pm PDT by Mitchel Broussard',
#  "Amazon today has Apple's Magic Keyboard for the 12.9-inch iPad Pro at its all-time best prices in both Black and White colors. You can get the Black model of the accessory for $324.88, down from $349.00. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site running. The...",
#  'Read Full Article 24 comments',
#  '',
#  "Deals: Save Up to 30% on Apple's MagSafe Charger Accessories for Your iPhone 12 or iPhone 13",
#  'Wednesday September 22, 2021 8:25 am PDT by Mitchel Broussard',
#  "A pair of solid deals on Apple's MagSafe Charger and MagSafe Duo Charger are still live at Amazon and Verizon, respectively. We first began tracking these all-time low prices one week ago, and it's a great time to buy them now at these prices, ahead of the iPhone 13 launch on Friday. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase,...",
#  'Read Full Article 17 comments',
#  '',
#  "Deals: Not Upgrading to iPhone 13? Amazon Has Apple's Official iPhone 11 and iPhone 12 Cases for Up to $30 Off",
#  'Tuesday September 21, 2021 8:18 am PDT by Mitchel Broussard',
#  "Now that a new family of iPhone models are launching this week, accessories for the previous generation devices are seeing notable discounts. On Amazon, you'll find Silicone, Leather, and Clear Cases for the iPhone 12 and iPhone 11 devices starting as low as $13.99. Note: MacRumors is an affiliate partner with Amazon. When you click a link and make a purchase, we may receive a small payment,...",
#  'Read Full Article 15 comments',
#  '',
#  'Deals: Amazon Introduces Its First iPad Mini 6 Discount, Get the 64GB Wi-Fi Tablet for $459.99 ($39 Off)',
#  'Monday September 20, 2021 8:04 am PDT by Mitchel Broussard',
#  "Following in the footsteps of Expercom and Walmart from last week, Amazon today has introduced its first ever discount on the new iPad mini 6. You'll find the 64GB Wi-Fi tablet in all colors except Purple at $459.99, down from $499.00. Note: MacRumors is an affiliate partner with Amazon. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site...",
#  'Read Full Article 22 comments',
#  '',
#  'Exclusive Deals: Get 40% Off a MagSafe-Compatible Car Mount for Your iPhone 13 and More in Our New Anker Sale',
#  'Monday September 20, 2021 7:43 am PDT by Mitchel Broussard',
#  "We've partnered with Anker again this week to bring our readers a collection of coupon codes that introduce notable discounts on Anker's best wall chargers, portable chargers, earbuds, and more. The highlight of the sale is a markdown on the Anker Magnetic Car Mount for iPhone 12 and iPhone 13, priced at $17.99 ($12 off) with our exclusive code. Note: MacRumors is an affiliate partner with...",
#  'Read Full Article 20 comments',
#  'Newer Posts',
#  'Archives',
#  'Older Posts',
#  'Guides',
#  'ios 17 ']

# %%
split_rdd = rdd.flatMap(lambda x: x.split(' '))
words = split_rdd.collect()
words
# Out:
# Out[41]: ['',
#  'Forums',
#  'Search',
#  'Site...',
#  'Apple',
#  'Vision',
#  'ProiOS',
#  '17iPhone',
#  '15iPhone',
#  '15',
#  'ProiPhone',
#  '16iPhone',
#  '16',
#  'PromacOS',
#  'SonomavisionOSwatchOS',
#  '10MacBook',
#  'Pro',
#  '14',
#  '&',
#  '16"HomePodiPhone',
#  '14Apple',
#  'TViPad',
#  'ProApple',
#  'Watch',
#  'Ultra',
#  '2iPadAirPods',
#  '3Apple',
#  'CarApple',
#  'Pro',
#  'Display',
#  'XDRHomePod',
#  'miniMac',
#  'ProMacBook',
#  'AiriPhone',
#  '13AirPods',
#  'MaxAirPods',
#  'ProApple',
#  'DealsApple',
#  'Studio',
#  'DisplayApple',
#  'Watch',
#  'SEMac',
#  'StudioiMaciPad',
#  'AiriPad',
#  'miniiPhone',
#  'SEMac',
#  'miniiOS',
#  '18Apple',
#  'Watch',
#  'Series',
#  '9CarPlayiPadOS',
#  '17Apple',
#  'Pay',
#  'All',
#  '>',
#  'MacRumors',
#  'iPhone',
#  'and',
#  'iPad',
#  'Blog:',
#  'Apps,',
#  'News,',
#  'and',
#  'Rumors',
#  'Apple',
#  'News',
#  'and',
#  'Rumors',
#  '',
#  'Deals:',
#  'Adorama',
#  'Introduces',
#  'New',
#  'Low',
#  'Prices',
#  'on',
#  '32GB',
#  'Apple',
#  'TV',
#  '4K',
#  '($159)',
#  'and',
#  'AirPods',
#  'Max',
#  '($449)',
#  'Tuesday',
#  'October',
#  '5,',
#  '2021',
#  '7:27',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  'Broussard',
#  'Adorama',
#  'today',
#  'has',
#  'a',
#  'collection',
#  'of',
#  'deals',
#  'on',
#  'select',
#  'Apple',
#  'products,',
#  'including',
#  'the',
#  'AirPods',
#  'Max,',
#  'Apple',
#  'TV',
#  '4K,',
#  'and',
#  'M1',
#  'MacBook',
#  'Pro.',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'Adorama.',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase,',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  'payment,',
#  'which',
#  'helps',
#  'us',
#  'keep',
#  'the',
#  'site',
#  'running.',
#  'Apple',
#  'TV',
#  '4K',
#  'You',
#  'can',
#  'get',
#  'the',
#  '32GB',
#  'Apple',
#  'TV',
#  '4K',
#  'for',
#  '$159.00,',
#  'down',
#  'from',
#  '$179.00.',
#  'This',
#  'is',
#  'a',
#  'new',
#  'all-time',
#  '...',
#  'Read',
#  'Full',
#  'Article',
#  '11',
#  'comments',
#  '',
#  'Deals:',
#  'Get',
#  '$10',
#  'Amazon',
#  'Credit',
#  'When',
#  'Purchasing',
#  'a',
#  '$100',
#  'Apple',
#  'Gift',
#  'Card',
#  'Monday',
#  'October',
#  '4,',
#  '2021',
#  '8:52',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  'Broussard',
#  'Amazon',
#  'today',
#  'is',
#  'offering',
#  '$10',
#  'in',
#  'Amazon',
#  'credit',
#  'when',
#  'you',
#  'spend',
#  '$100',
#  'or',
#  'more',
#  'on',
#  'the',
#  'Apple',
#  'Gift',
#  'Card.',
#  'This',
#  'card',
#  'is',
#  'digital',
#  'and',
#  'will',
#  'be',
#  'delivered',
#  'to',
#  'you',
#  'via',
#  'email,',
#  'and',
#  'the',
#  'offer',
#  'will',
#  'automatically',
#  'be',
#  'applied',
#  'at',
#  'the',
#  'checkout',
#  'screen.',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors.',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase,',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  'payment,',
#  'which',
#  'helps',
#  'us',
#  'keep',
#  'the...',
#  'Read',
#  'Full',
#  'Article',
#  '44',
#  'comments',
#  '',
#  'Deals:',
#  'New',
#  'Sales',
#  'Hit',
#  'Every',
#  'AirPods',
#  'Model,',
#  'Starting',
#  'at',
#  '$109',
#  'for',
#  'Regular',
#  'AirPods',
#  'Monday',
#  'October',
#  '4,',
#  '2021',
#  '7:49',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  'Broussard',
#  'Today',
#  "we're",
#  'tracking',
#  'new',
#  'sales',
#  'on',
#  'every',
#  'model',
#  'of',
#  "Apple's",
#  'AirPods,',
#  'starting',
#  'with',
#  'a',
#  'return',
#  'of',
#  'the',
#  'lowest-ever',
#  'price',
#  'on',
#  'the',
#  'AirPods',
#  'with',
#  'Wireless',
#  'Charging',
#  'Case',
#  'on',
#  'Amazon,',
#  'priced',
#  'at',
#  '$129.00,',
#  'down',
#  'from',
#  '$199.00.',
#  'Below',
#  "you'll",
#  'also',
#  'find',
#  'sales',
#  'on',
#  'the',
#  'AirPods',
#  'with',
#  'Wired',
#  'Charging',
#  'Case,',
#  'AirPods',
#  'Pro,',
#  'and',
#  'AirPods',
#  'Max.',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'these',
#  'vendors.',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  '...',
#  'Read',
#  'Full',
#  'Article',
#  '13',
#  'comments',
#  '',
#  'Deals:',
#  'Take',
#  'Up',
#  'To',
#  '$100',
#  'Off',
#  '2021',
#  'iPad',
#  'Pro',
#  'Tablets',
#  'at',
#  'Amazon',
#  'Friday',
#  'October',
#  '1,',
#  '2021',
#  '7:28',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  'Broussard',
#  'Amazon',
#  'today',
#  'has',
#  'a',
#  'few',
#  'deals',
#  'on',
#  'the',
#  '2021',
#  'iPad',
#  'Pro',
#  'in',
#  'both',
#  '11-inch',
#  'and',
#  '12.9-inch',
#  'configurations.',
#  "You'll",
#  'have',
#  'a',
#  'chance',
#  'to',
#  'save',
#  'up',
#  'to',
#  '$100',
#  'on',
#  'these',
#  'models,',
#  'and',
#  'this',
#  'sale',
#  'focuses',
#  'on',
#  'Wi-Fi',
#  'only',
#  'tablets',
#  'and',
#  "they're",
#  'all',
#  'available',
#  'on',
#  'Amazon.',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'Amazon.',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase,',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  'payment,',
#  'which',
#  'helps',
#  'us',
#  'keep',
#  'the',
#  'site...',
#  'Read',
#  'Full',
#  'Article',
#  '2',
#  'comments',
#  '',
#  'Deals:',
#  "Apple's",
#  'MagSafe',
#  'Battery',
#  'Pack',
#  'Drops',
#  'to',
#  '$84.15',
#  '($15',
#  'Off)',
#  'Thursday',
#  'September',
#  '30,',
#  '2021',
#  '11:22',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  'Broussard',
#  'Yesterday',
#  'we',
#  'shared',
#  'a',
#  'new',
#  'discount',
#  'event',
#  'happening',
#  'at',
#  'AT&T,',
#  'where',
#  'you',
#  'can',
#  'get',
#  '15',
#  'percent',
#  'off',
#  'select',
#  'Apple',
#  'accessories',
#  'this',
#  'fall.',
#  'One',
#  'notable',
#  'accessory',
#  'in',
#  'the',
#  'sale',
#  'was',
#  'the',
#  'MagSafe',
#  'Battery',
#  'Pack,',
#  'but',
#  'it',
#  'was',
#  'out',
#  'of',
#  'stock.',
#  'Today,',
#  'however,',
#  "that's",
#  'changed,',
#  'and',
#  'you',
#  'can',
#  'now',
#  'order',
#  'the',
#  'MagSafe',
#  'Battery',
#  'Pack',
#  'for',
#  '$84.15,',
#  'down',
#  'from',
#  '$99.00.',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors....',
#  'Read',
#  'Full',
#  'Article',
#  '19',
#  'comments',
#  '',
#  'Deals:',
#  'Get',
#  '20%',
#  'Off',
#  "Hyper's",
#  '18W',
#  'Battery',
#  'Packs',
#  'and',
#  "Satechi's",
#  '100W',
#  'USB-C',
#  'Wall',
#  'Charger',
#  'Thursday',
#  'September',
#  '30,',
#  '2021',
#  '8:18',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  'Broussard',
#  'Today',
#  'we',
#  'have',
#  'a',
#  'pair',
#  'of',
#  'charging-related',
#  'deals',
#  'from',
#  'Hyper',
#  'and',
#  'Satechi,',
#  'which',
#  'are',
#  'offering',
#  '20',
#  'percent',
#  'off',
#  'a',
#  'portable',
#  'battery',
#  'and',
#  'USB-C',
#  'wall',
#  'charger,',
#  'respectively.',
#  "Hyper's",
#  'sale',
#  'will',
#  'end',
#  'later',
#  'today,',
#  'while',
#  "Satechi's",
#  'will',
#  'run',
#  'for',
#  'one',
#  'week,',
#  'through',
#  'October',
#  '7.',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors.',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase,',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small...',
#  'Read',
#  'Full',
#  'Article',
#  '12',
#  'comments',
#  '',
#  'Deals:',
#  'AT&T',
#  'Taking',
#  '15%',
#  'Off',
#  "Apple's",
#  'MagSafe',
#  'Accessories',
#  'Wednesday',
#  'September',
#  '29,',
#  '2021',
#  '7:58',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  'Broussard',
#  'Today',
#  'at',
#  'AT&T',
#  'you',
#  'can',
#  'get',
#  '15',
#  'percent',
#  'off',
#  'a',
#  'wide',
#  'selection',
#  'of',
#  "Apple's",
#  'MagSafe',
#  'accessories,',
#  'including',
#  'Clear,',
#  'Silicone,',
#  'and',
#  'Leather',
#  'Cases',
#  'for',
#  'the',
#  'iPhone',
#  '13,',
#  '13',
#  'mini,',
#  '13',
#  'Pro,',
#  'and',
#  '13',
#  'Pro',
#  'Max.',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors.',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase,',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  'payment,',
#  'which',
#  'helps',
#  'us',
#  'keep',
#  'the',
#  'site',
#  'running.',
#  'Sale',
#  'prices',
#  'have',
#  'been...',
#  'Read',
#  'Full',
#  'Article',
#  '13',
#  'comments',
#  '',
#  'Deals:',
#  'Get',
#  "Apple's",
#  '256GB',
#  'Wi-Fi',
#  'iPad',
#  'Air',
#  'for',
#  '$649.99',
#  '($99',
#  'Off)',
#  'Tuesday',
#  'September',
#  '28,',
#  '2021',
#  '10:05',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  'Broussard',
#  'Amazon',
#  'today',
#  'has',
#  'the',
#  '256GB',
#  'iPad',
#  'Air',
#  'for',
#  '$649.99,',
#  'down',
#  'from',
#  '$749.00.',
#  'This',
#  'sale',
#  'price',
#  'is',
#  'available',
#  'in',
#  'Rose',
#  'Gold,',
#  'Silver,',
#  'Sky',
#  'Blue,',
#  'and',
#  'Space',
#  'Gray,',
#  'but',
#  'only',
#  'Rose',
#  'Gold',
#  'is',
#  'available',
#  'to',
#  'ship',
#  'out',
#  'today.',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors.',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase,',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  'payment,',
#  'which',
#  'helps',
#  'us',
#  'keep',
#  'the',
#  'site',
#  'running.',
#  'This',
#  'same',
#  'sale...',
#  'Read',
#  'Full',
#  'Article',
#  '3',
#  'comments',
#  '',
#  'Deals:',
#  'Verizon',
#  'Offering',
#  'Up',
#  'to',
#  '30%',
#  'Off',
#  'MagSafe',
#  'Accessory',
#  'Bundles,',
#  'iPhone',
#  '13',
#  'Cases,',
#  'and',
#  'More',
#  'Monday',
#  'September',
#  '27,',
#  '2021',
#  '11:53',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  'Broussard',
#  'Today',
#  "we're",
#  'tracking',
#  'a',
#  'handful',
#  'of',
#  'solid',
#  'accessory',
#  'discounts',
#  'offered',
#  'by',
#  'Verizon,',
#  'offering',
#  'a',
#  'chance',
#  'to',
#  'save',
#  'on',
#  'a',
#  'new',
#  'case',
#  'or',
#  'screen',
#  'protector',
#  'for',
#  'your',
#  'iPhone',
#  '13,',
#  'MagSafe',
#  'bundles,',
#  'and',
#  'more.',
#  'Verizon',
#  'offers',
#  'free',
#  'two',
#  'day',
#  'shipping',
#  'across',
#  'the',
#  'board',
#  'on',
#  'orders',
#  'over',
#  '$49,',
#  'even',
#  'if',
#  'you',
#  "don't",
#  'use',
#  'Verizon',
#  'as',
#  'a',
#  'carrier.',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors.',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link...',
#  'Read',
#  'Full',
#  'Article',
#  '10',
#  'comments',
#  '',
#  'Deals:',
#  'Get',
#  'Up',
#  'to',
#  '45%',
#  'Off',
#  "Anker's",
#  'USB-C',
#  'Chargers,',
#  'MagSafe-Compatible',
#  'Accessories,',
#  'and',
#  'More',
#  'Monday',
#  'September',
#  '27,',
#  '2021',
#  '8:39',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  'Broussard',
#  'Anker',
#  'today',
#  'introduced',
#  'a',
#  'new',
#  'Gold',
#  'Box',
#  'sale',
#  'on',
#  'Amazon,',
#  'taking',
#  'up',
#  'to',
#  '45',
#  'percent',
#  'off',
#  'select',
#  'accessories',
#  ...]

# %%
word_freq = split_rdd.map(lambda x: (x,1))
word_freq.collect()
# Out:
# Out[42]: [('', 1),
#  ('Forums', 1),
#  ('Search', 1),
#  ('Site...', 1),
#  ('Apple', 1),
#  ('Vision', 1),
#  ('ProiOS', 1),
#  ('17iPhone', 1),
#  ('15iPhone', 1),
#  ('15', 1),
#  ('ProiPhone', 1),
#  ('16iPhone', 1),
#  ('16', 1),
#  ('PromacOS', 1),
#  ('SonomavisionOSwatchOS', 1),
#  ('10MacBook', 1),
#  ('Pro', 1),
#  ('14', 1),
#  ('&', 1),
#  ('16"HomePodiPhone', 1),
#  ('14Apple', 1),
#  ('TViPad', 1),
#  ('ProApple', 1),
#  ('Watch', 1),
#  ('Ultra', 1),
#  ('2iPadAirPods', 1),
#  ('3Apple', 1),
#  ('CarApple', 1),
#  ('Pro', 1),
#  ('Display', 1),
#  ('XDRHomePod', 1),
#  ('miniMac', 1),
#  ('ProMacBook', 1),
#  ('AiriPhone', 1),
#  ('13AirPods', 1),
#  ('MaxAirPods', 1),
#  ('ProApple', 1),
#  ('DealsApple', 1),
#  ('Studio', 1),
#  ('DisplayApple', 1),
#  ('Watch', 1),
#  ('SEMac', 1),
#  ('StudioiMaciPad', 1),
#  ('AiriPad', 1),
#  ('miniiPhone', 1),
#  ('SEMac', 1),
#  ('miniiOS', 1),
#  ('18Apple', 1),
#  ('Watch', 1),
#  ('Series', 1),
#  ('9CarPlayiPadOS', 1),
#  ('17Apple', 1),
#  ('Pay', 1),
#  ('All', 1),
#  ('>', 1),
#  ('MacRumors', 1),
#  ('iPhone', 1),
#  ('and', 1),
#  ('iPad', 1),
#  ('Blog:', 1),
#  ('Apps,', 1),
#  ('News,', 1),
#  ('and', 1),
#  ('Rumors', 1),
#  ('Apple', 1),
#  ('News', 1),
#  ('and', 1),
#  ('Rumors', 1),
#  ('', 1),
#  ('Deals:', 1),
#  ('Adorama', 1),
#  ('Introduces', 1),
#  ('New', 1),
#  ('Low', 1),
#  ('Prices', 1),
#  ('on', 1),
#  ('32GB', 1),
#  ('Apple', 1),
#  ('TV', 1),
#  ('4K', 1),
#  ('($159)', 1),
#  ('and', 1),
#  ('AirPods', 1),
#  ('Max', 1),
#  ('($449)', 1),
#  ('Tuesday', 1),
#  ('October', 1),
#  ('5,', 1),
#  ('2021', 1),
#  ('7:27', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ('Broussard', 1),
#  ('Adorama', 1),
#  ('today', 1),
#  ('has', 1),
#  ('a', 1),
#  ('collection', 1),
#  ('of', 1),
#  ('deals', 1),
#  ('on', 1),
#  ('select', 1),
#  ('Apple', 1),
#  ('products,', 1),
#  ('including', 1),
#  ('the', 1),
#  ('AirPods', 1),
#  ('Max,', 1),
#  ('Apple', 1),
#  ('TV', 1),
#  ('4K,', 1),
#  ('and', 1),
#  ('M1', 1),
#  ('MacBook', 1),
#  ('Pro.', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('Adorama.', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase,', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('payment,', 1),
#  ('which', 1),
#  ('helps', 1),
#  ('us', 1),
#  ('keep', 1),
#  ('the', 1),
#  ('site', 1),
#  ('running.', 1),
#  ('Apple', 1),
#  ('TV', 1),
#  ('4K', 1),
#  ('You', 1),
#  ('can', 1),
#  ('get', 1),
#  ('the', 1),
#  ('32GB', 1),
#  ('Apple', 1),
#  ('TV', 1),
#  ('4K', 1),
#  ('for', 1),
#  ('$159.00,', 1),
#  ('down', 1),
#  ('from', 1),
#  ('$179.00.', 1),
#  ('This', 1),
#  ('is', 1),
#  ('a', 1),
#  ('new', 1),
#  ('all-time', 1),
#  ('...', 1),
#  ('Read', 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('11', 1),
#  ('comments', 1),
#  ('', 1),
#  ('Deals:', 1),
#  ('Get', 1),
#  ('$10', 1),
#  ('Amazon', 1),
#  ('Credit', 1),
#  ('When', 1),
#  ('Purchasing', 1),
#  ('a', 1),
#  ('$100', 1),
#  ('Apple', 1),
#  ('Gift', 1),
#  ('Card', 1),
#  ('Monday', 1),
#  ('October', 1),
#  ('4,', 1),
#  ('2021', 1),
#  ('8:52', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ('Broussard', 1),
#  ('Amazon', 1),
#  ('today', 1),
#  ('is', 1),
#  ('offering', 1),
#  ('$10', 1),
#  ('in', 1),
#  ('Amazon', 1),
#  ('credit', 1),
#  ('when', 1),
#  ('you', 1),
#  ('spend', 1),
#  ('$100', 1),
#  ('or', 1),
#  ('more', 1),
#  ('on', 1),
#  ('the', 1),
#  ('Apple', 1),
#  ('Gift', 1),
#  ('Card.', 1),
#  ('This', 1),
#  ('card', 1),
#  ('is', 1),
#  ('digital', 1),
#  ('and', 1),
#  ('will', 1),
#  ('be', 1),
#  ('delivered', 1),
#  ('to', 1),
#  ('you', 1),
#  ('via', 1),
#  ('email,', 1),
#  ('and', 1),
#  ('the', 1),
#  ('offer', 1),
#  ('will', 1),
#  ('automatically', 1),
#  ('be', 1),
#  ('applied', 1),
#  ('at', 1),
#  ('the', 1),
#  ('checkout', 1),
#  ('screen.', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors.', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase,', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('payment,', 1),
#  ('which', 1),
#  ('helps', 1),
#  ('us', 1),
#  ('keep', 1),
#  ('the...', 1),
#  ('Read', 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('44', 1),
#  ('comments', 1),
#  ('', 1),
#  ('Deals:', 1),
#  ('New', 1),
#  ('Sales', 1),
#  ('Hit', 1),
#  ('Every', 1),
#  ('AirPods', 1),
#  ('Model,', 1),
#  ('Starting', 1),
#  ('at', 1),
#  ('$109', 1),
#  ('for', 1),
#  ('Regular', 1),
#  ('AirPods', 1),
#  ('Monday', 1),
#  ('October', 1),
#  ('4,', 1),
#  ('2021', 1),
#  ('7:49', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ('Broussard', 1),
#  ('Today', 1),
#  ("we're", 1),
#  ('tracking', 1),
#  ('new', 1),
#  ('sales', 1),
#  ('on', 1),
#  ('every', 1),
#  ('model', 1),
#  ('of', 1),
#  ("Apple's", 1),
#  ('AirPods,', 1),
#  ('starting', 1),
#  ('with', 1),
#  ('a', 1),
#  ('return', 1),
#  ('of', 1),
#  ('the', 1),
#  ('lowest-ever', 1),
#  ('price', 1),
#  ('on', 1),
#  ('the', 1),
#  ('AirPods', 1),
#  ('with', 1),
#  ('Wireless', 1),
#  ('Charging', 1),
#  ('Case', 1),
#  ('on', 1),
#  ('Amazon,', 1),
#  ('priced', 1),
#  ('at', 1),
#  ('$129.00,', 1),
#  ('down', 1),
#  ('from', 1),
#  ('$199.00.', 1),
#  ('Below', 1),
#  ("you'll", 1),
#  ('also', 1),
#  ('find', 1),
#  ('sales', 1),
#  ('on', 1),
#  ('the', 1),
#  ('AirPods', 1),
#  ('with', 1),
#  ('Wired', 1),
#  ('Charging', 1),
#  ('Case,', 1),
#  ('AirPods', 1),
#  ('Pro,', 1),
#  ('and', 1),
#  ('AirPods', 1),
#  ('Max.', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('these', 1),
#  ('vendors.', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('...', 1),
#  ('Read', 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('13', 1),
#  ('comments', 1),
#  ('', 1),
#  ('Deals:', 1),
#  ('Take', 1),
#  ('Up', 1),
#  ('To', 1),
#  ('$100', 1),
#  ('Off', 1),
#  ('2021', 1),
#  ('iPad', 1),
#  ('Pro', 1),
#  ('Tablets', 1),
#  ('at', 1),
#  ('Amazon', 1),
#  ('Friday', 1),
#  ('October', 1),
#  ('1,', 1),
#  ('2021', 1),
#  ('7:28', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ('Broussard', 1),
#  ('Amazon', 1),
#  ('today', 1),
#  ('has', 1),
#  ('a', 1),
#  ('few', 1),
#  ('deals', 1),
#  ('on', 1),
#  ('the', 1),
#  ('2021', 1),
#  ('iPad', 1),
#  ('Pro', 1),
#  ('in', 1),
#  ('both', 1),
#  ('11-inch', 1),
#  ('and', 1),
#  ('12.9-inch', 1),
#  ('configurations.', 1),
#  ("You'll", 1),
#  ('have', 1),
#  ('a', 1),
#  ('chance', 1),
#  ('to', 1),
#  ('save', 1),
#  ('up', 1),
#  ('to', 1),
#  ('$100', 1),
#  ('on', 1),
#  ('these', 1),
#  ('models,', 1),
#  ('and', 1),
#  ('this', 1),
#  ('sale', 1),
#  ('focuses', 1),
#  ('on', 1),
#  ('Wi-Fi', 1),
#  ('only', 1),
#  ('tablets', 1),
#  ('and', 1),
#  ("they're", 1),
#  ('all', 1),
#  ('available', 1),
#  ('on', 1),
#  ('Amazon.', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('Amazon.', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase,', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('payment,', 1),
#  ('which', 1),
#  ('helps', 1),
#  ('us', 1),
#  ('keep', 1),
#  ('the', 1),
#  ('site...', 1),
#  ('Read', 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('2', 1),
#  ('comments', 1),
#  ('', 1),
#  ('Deals:', 1),
#  ("Apple's", 1),
#  ('MagSafe', 1),
#  ('Battery', 1),
#  ('Pack', 1),
#  ('Drops', 1),
#  ('to', 1),
#  ('$84.15', 1),
#  ('($15', 1),
#  ('Off)', 1),
#  ('Thursday', 1),
#  ('September', 1),
#  ('30,', 1),
#  ('2021', 1),
#  ('11:22', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ('Broussard', 1),
#  ('Yesterday', 1),
#  ('we', 1),
#  ('shared', 1),
#  ('a', 1),
#  ('new', 1),
#  ('discount', 1),
#  ('event', 1),
#  ('happening', 1),
#  ('at', 1),
#  ('AT&T,', 1),
#  ('where', 1),
#  ('you', 1),
#  ('can', 1),
#  ('get', 1),
#  ('15', 1),
#  ('percent', 1),
#  ('off', 1),
#  ('select', 1),
#  ('Apple', 1),
#  ('accessories', 1),
#  ('this', 1),
#  ('fall.', 1),
#  ('One', 1),
#  ('notable', 1),
#  ('accessory', 1),
#  ('in', 1),
#  ('the', 1),
#  ('sale', 1),
#  ('was', 1),
#  ('the', 1),
#  ('MagSafe', 1),
#  ('Battery', 1),
#  ('Pack,', 1),
#  ('but', 1),
#  ('it', 1),
#  ('was', 1),
#  ('out', 1),
#  ('of', 1),
#  ('stock.', 1),
#  ('Today,', 1),
#  ('however,', 1),
#  ("that's", 1),
#  ('changed,', 1),
#  ('and', 1),
#  ('you', 1),
#  ('can', 1),
#  ('now', 1),
#  ('order', 1),
#  ('the', 1),
#  ('MagSafe', 1),
#  ('Battery', 1),
#  ('Pack', 1),
#  ('for', 1),
#  ('$84.15,', 1),
#  ('down', 1),
#  ('from', 1),
#  ('$99.00.', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors....', 1),
#  ('Read', 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('19', 1),
#  ('comments', 1),
#  ('', 1),
#  ('Deals:', 1),
#  ('Get', 1),
#  ('20%', 1),
#  ('Off', 1),
#  ("Hyper's", 1),
#  ('18W', 1),
#  ('Battery', 1),
#  ('Packs', 1),
#  ('and', 1),
#  ("Satechi's", 1),
#  ('100W', 1),
#  ('USB-C', 1),
#  ('Wall', 1),
#  ('Charger', 1),
#  ('Thursday', 1),
#  ('September', 1),
#  ('30,', 1),
#  ('2021', 1),
#  ('8:18', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ('Broussard', 1),
#  ('Today', 1),
#  ('we', 1),
#  ('have', 1),
#  ('a', 1),
#  ('pair', 1),
#  ('of', 1),
#  ('charging-related', 1),
#  ('deals', 1),
#  ('from', 1),
#  ('Hyper', 1),
#  ('and', 1),
#  ('Satechi,', 1),
#  ('which', 1),
#  ('are', 1),
#  ('offering', 1),
#  ('20', 1),
#  ('percent', 1),
#  ('off', 1),
#  ('a', 1),
#  ('portable', 1),
#  ('battery', 1),
#  ('and', 1),
#  ('USB-C', 1),
#  ('wall', 1),
#  ('charger,', 1),
#  ('respectively.', 1),
#  ("Hyper's", 1),
#  ('sale', 1),
#  ('will', 1),
#  ('end', 1),
#  ('later', 1),
#  ('today,', 1),
#  ('while', 1),
#  ("Satechi's", 1),
#  ('will', 1),
#  ('run', 1),
#  ('for', 1),
#  ('one', 1),
#  ('week,', 1),
#  ('through', 1),
#  ('October', 1),
#  ('7.', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors.', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase,', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small...', 1),
#  ('Read', 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('12', 1),
#  ('comments', 1),
#  ('', 1),
#  ('Deals:', 1),
#  ('AT&T', 1),
#  ('Taking', 1),
#  ('15%', 1),
#  ('Off', 1),
#  ("Apple's", 1),
#  ('MagSafe', 1),
#  ('Accessories', 1),
#  ('Wednesday', 1),
#  ('September', 1),
#  ('29,', 1),
#  ('2021', 1),
#  ('7:58', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ('Broussard', 1),
#  ('Today', 1),
#  ('at', 1),
#  ('AT&T', 1),
#  ('you', 1),
#  ('can', 1),
#  ('get', 1),
#  ('15', 1),
#  ('percent', 1),
#  ('off', 1),
#  ('a', 1),
#  ('wide', 1),
#  ('selection', 1),
#  ('of', 1),
#  ("Apple's", 1),
#  ('MagSafe', 1),
#  ('accessories,', 1),
#  ('including', 1),
#  ('Clear,', 1),
#  ('Silicone,', 1),
#  ('and', 1),
#  ('Leather', 1),
#  ('Cases', 1),
#  ('for', 1),
#  ('the', 1),
#  ('iPhone', 1),
#  ('13,', 1),
#  ('13', 1),
#  ('mini,', 1),
#  ('13', 1),
#  ('Pro,', 1),
#  ('and', 1),
#  ('13', 1),
#  ('Pro', 1),
#  ('Max.', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors.', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase,', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('payment,', 1),
#  ('which', 1),
#  ('helps', 1),
#  ('us', 1),
#  ('keep', 1),
#  ('the', 1),
#  ('site', 1),
#  ('running.', 1),
#  ('Sale', 1),
#  ('prices', 1),
#  ('have', 1),
#  ('been...', 1),
#  ('Read', 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('13', 1),
#  ('comments', 1),
#  ('', 1),
#  ('Deals:', 1),
#  ('Get', 1),
#  ("Apple's", 1),
#  ('256GB', 1),
#  ('Wi-Fi', 1),
#  ('iPad', 1),
#  ('Air', 1),
#  ('for', 1),
#  ('$649.99', 1),
#  ('($99', 1),
#  ('Off)', 1),
#  ('Tuesday', 1),
#  ('September', 1),
#  ('28,', 1),
#  ('2021', 1),
#  ('10:05', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ('Broussard', 1),
#  ('Amazon', 1),
#  ('today', 1),
#  ('has', 1),
#  ('the', 1),
#  ('256GB', 1),
#  ('iPad', 1),
#  ('Air', 1),
#  ('for', 1),
#  ('$649.99,', 1),
#  ('down', 1),
#  ('from', 1),
#  ('$749.00.', 1),
#  ('This', 1),
#  ('sale', 1),
#  ('price', 1),
#  ('is', 1),
#  ('available', 1),
#  ('in', 1),
#  ('Rose', 1),
#  ('Gold,', 1),
#  ('Silver,', 1),
#  ('Sky', 1),
#  ('Blue,', 1),
#  ('and', 1),
#  ('Space', 1),
#  ('Gray,', 1),
#  ('but', 1),
#  ('only', 1),
#  ('Rose', 1),
#  ('Gold', 1),
#  ('is', 1),
#  ('available', 1),
#  ('to', 1),
#  ('ship', 1),
#  ('out', 1),
#  ('today.', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors.', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase,', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('payment,', 1),
#  ('which', 1),
#  ('helps', 1),
#  ('us', 1),
#  ('keep', 1),
#  ('the', 1),
#  ('site', 1),
#  ('running.', 1),
#  ('This', 1),
#  ('same', 1),
#  ('sale...', 1),
#  ('Read', 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('3', 1),
#  ('comments', 1),
#  ('', 1),
#  ('Deals:', 1),
#  ('Verizon', 1),
#  ('Offering', 1),
#  ('Up', 1),
#  ('to', 1),
#  ('30%', 1),
#  ('Off', 1),
#  ('MagSafe', 1),
#  ('Accessory', 1),
#  ('Bundles,', 1),
#  ('iPhone', 1),
#  ('13', 1),
#  ('Cases,', 1),
#  ('and', 1),
#  ('More', 1),
#  ('Monday', 1),
#  ('September', 1),
#  ('27,', 1),
#  ('2021', 1),
#  ('11:53', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ('Broussard', 1),
#  ('Today', 1),
#  ("we're", 1),
#  ('tracking', 1),
#  ('a', 1),
#  ('handful', 1),
#  ('of', 1),
#  ('solid', 1),
#  ('accessory', 1),
#  ('discounts', 1),
#  ('offered', 1),
#  ('by', 1),
#  ('Verizon,', 1),
#  ('offering', 1),
#  ('a', 1),
#  ('chance', 1),
#  ('to', 1),
#  ('save', 1),
#  ('on', 1),
#  ('a', 1),
#  ('new', 1),
#  ('case', 1),
#  ('or', 1),
#  ('screen', 1),
#  ('protector', 1),
#  ('for', 1),
#  ('your', 1),
#  ('iPhone', 1),
#  ('13,', 1),
#  ('MagSafe', 1),
#  ('bundles,', 1),
#  ('and', 1),
#  ('more.', 1),
#  ('Verizon', 1),
#  ('offers', 1),
#  ('free', 1),
#  ('two', 1),
#  ('day', 1),
#  ('shipping', 1),
#  ('across', 1),
#  ('the', 1),
#  ('board', 1),
#  ('on', 1),
#  ('orders', 1),
#  ('over', 1),
#  ('$49,', 1),
#  ('even', 1),
#  ('if', 1),
#  ('you', 1),
#  ("don't", 1),
#  ('use', 1),
#  ('Verizon', 1),
#  ('as', 1),
#  ('a', 1),
#  ('carrier.', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors.', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link...', 1),
#  ('Read', 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('10', 1),
#  ('comments', 1),
#  ('', 1),
#  ('Deals:', 1),
#  ('Get', 1),
#  ('Up', 1),
#  ('to', 1),
#  ('45%', 1),
#  ('Off', 1),
#  ("Anker's", 1),
#  ('USB-C', 1),
#  ('Chargers,', 1),
#  ('MagSafe-Compatible', 1),
#  ('Accessories,', 1),
#  ('and', 1),
#  ('More', 1),
#  ('Monday', 1),
#  ('September', 1),
#  ('27,', 1),
#  ('2021', 1),
#  ('8:39', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ('Broussard', 1),
#  ('Anker', 1),
#  ('today', 1),
#  ('introduced', 1),
#  ('a', 1),
#  ('new', 1),
#  ('Gold', 1),
#  ('Box', 1),
#  ('sale', 1),
#  ('on', 1),
#  ('Amazon,', 1),
#  ('taking', 1),
#  ('up', 1),
#  ('to', 1),
#  ('45', 1),
#  ('percent', 1),
#  ('off', 1),
#  ('select', 1),
#  ('accessories', 1),
#  ...]

# %%
count_rdd = word_freq.reduceByKey(lambda a,b: a+b)
count_rdd.collect()
# Out:
# Out[43]: [('', 20),
#  ('Site...', 1),
#  ('Apple', 10),
#  ('ProiOS', 1),
#  ('17iPhone', 1),
#  ('15iPhone', 1),
#  ('ProiPhone', 1),
#  ('16', 1),
#  ('SonomavisionOSwatchOS', 1),
#  ('Pro', 7),
#  ('14', 1),
#  ('16"HomePodiPhone', 1),
#  ('Watch', 3),
#  ('Ultra', 1),
#  ('CarApple', 1),
#  ('XDRHomePod', 1),
#  ('miniMac', 1),
#  ('ProMacBook', 1),
#  ('DealsApple', 1),
#  ('DisplayApple', 1),
#  ('StudioiMaciPad', 1),
#  ('miniiPhone', 1),
#  ('miniiOS', 1),
#  ('Series', 1),
#  ('9CarPlayiPadOS', 1),
#  ('>', 1),
#  ('iPhone', 19),
#  ('iPad', 10),
#  ('Apps,', 1),
#  ('News,', 1),
#  ('News', 1),
#  ('Adorama', 2),
#  ('New', 5),
#  ('Low', 1),
#  ('Prices', 2),
#  ('32GB', 2),
#  ('TV', 4),
#  ('7:27', 1),
#  ('am', 17),
#  ('Mitchel', 18),
#  ('collection', 2),
#  ('of', 32),
#  ('deals', 5),
#  ('select', 3),
#  ('products,', 1),
#  ('M1', 1),
#  ('Note:', 18),
#  ('is', 26),
#  ('an', 19),
#  ('Adorama.', 1),
#  ('When', 17),
#  ('click', 16),
#  ('make', 15),
#  ('we', 15),
#  ('may', 12),
#  ('us', 9),
#  ('site', 5),
#  ('running.', 5),
#  ('down', 7),
#  ('$179.00.', 1),
#  ('new', 10),
#  ('...', 2),
#  ('comments', 18),
#  ('Get', 7),
#  ('$10', 2),
#  ('Credit', 1),
#  ('Purchasing', 1),
#  ('$100', 4),
#  ('Gift', 3),
#  ('Card', 2),
#  ('Monday', 6),
#  ('4,', 2),
#  ('8:52', 1),
#  ('offering', 3),
#  ('in', 10),
#  ('when', 2),
#  ('more', 1),
#  ('card', 1),
#  ('via', 1),
#  ('applied', 1),
#  ('at', 14),
#  ('checkout', 1),
#  ('screen.', 1),
#  ('these', 15),
#  ('vendors.', 11),
#  ('the...', 1),
#  ('44', 1),
#  ('Sales', 1),
#  ('Hit', 2),
#  ('Every', 1),
#  ('Starting', 2),
#  ('Today', 4),
#  ('tracking', 3),
#  ('model', 3),
#  ("Apple's", 10),
#  ('AirPods,', 1),
#  ('starting', 2),
#  ('lowest-ever', 1),
#  ('price', 3),
#  ('Charging', 2),
#  ('Amazon,', 3),
#  ('Below', 1),
#  ("you'll", 2),
#  ('Wired', 1),
#  ('Pro,', 2),
#  ('Up', 5),
#  ('Off', 8),
#  ('Tablets', 1),
#  ('Friday', 2),
#  ('1,', 1),
#  ('both', 2),
#  ('12.9-inch', 2),
#  ("You'll", 2),
#  ('have', 3),
#  ('chance', 2),
#  ('save', 3),
#  ('models,', 1),
#  ('this', 5),
#  ('sale', 7),
#  ('Wi-Fi', 6),
#  ('only', 3),
#  ('Drops', 2),
#  ('$84.15', 1),
#  ('Off)', 4),
#  ('Thursday', 4),
#  ('11:22', 1),
#  ('Yesterday', 1),
#  ('event', 1),
#  ('happening', 1),
#  ('where', 1),
#  ('accessories', 3),
#  ('fall.', 1),
#  ('One', 1),
#  ('notable', 3),
#  ('accessory', 3),
#  ('was', 2),
#  ('but', 2),
#  ('out', 2),
#  ('stock.', 1),
#  ('however,', 1),
#  ('now', 2),
#  ('vendors....', 1),
#  ('19', 1),
#  ('18W', 1),
#  ('Packs', 1),
#  ("Satechi's", 4),
#  ('100W', 1),
#  ('charging-related', 1),
#  ('Hyper', 1),
#  ('are', 5),
#  ('20', 3),
#  ('portable', 3),
#  ('battery', 1),
#  ('charger,', 1),
#  ('respectively.', 2),
#  ('end', 1),
#  ('today,', 2),
#  ('run', 1),
#  ('12', 8),
#  ('AT&T', 2),
#  ('15%', 1),
#  ('Accessories', 2),
#  ('29,', 1),
#  ('13,', 3),
#  ('mini,', 1),
#  ('Air', 2),
#  ('($99', 1),
#  ('28,', 1),
#  ('$649.99,', 1),
#  ('Rose', 2),
#  ('Sky', 1),
#  ('Space', 2),
#  ('Gray,', 1),
#  ('today.', 1),
#  ('Offering', 1),
#  ('Cases,', 1),
#  ('27,', 2),
#  ('handful', 1),
#  ('offered', 1),
#  ('Verizon,', 2),
#  ('protector', 1),
#  ('offers', 1),
#  ('free', 1),
#  ('two', 2),
#  ('board', 1),
#  ('orders', 1),
#  ('$49,', 1),
#  ('even', 1),
#  ('use', 1),
#  ('as', 3),
#  ('carrier.', 1),
#  ('10', 1),
#  ('45%', 1),
#  ("Anker's", 2),
#  ('Accessories,', 1),
#  ('Anker', 4),
#  ('introduced', 2),
#  ('Box', 1),
#  ('45', 1),
#  ('only.', 1),
#  ('include', 1),
#  ('savings', 1),
#  ('chargers,', 3),
#  ('batteries,', 1),
#  ('wireless', 1),
#  ('chargers.', 1),
#  ('$200', 1),
#  ('Free', 1),
#  ('Mini', 2),
#  ('Purchase', 1),
#  ('7:19', 1),
#  ("It's", 1),
#  ('anyone', 1),
#  ('smartphone', 1),
#  ('options', 1),
#  ('purchase', 1),
#  ('iPhone.', 1),
#  ('highlighting', 1),
#  ('deal', 1),
#  ('Verizon-owned', 1),
#  ('Wireless,', 1),
#  ('low-cost', 1),
#  ('alternative', 1),
#  ('name', 1),
#  ('carriers.', 1),
#  ('Price', 1),
#  ('$299.00', 1),
#  ('($30', 1),
#  ('23,', 2),
#  ('The', 2),
#  ('10.2-inch', 1),
#  ('$299.00,', 1),
#  ('$329.00.', 1),
#  ('Gray', 1),
#  ('Dual', 1),
#  ('Chargers', 1),
#  ('Satechi', 1),
#  ('trio', 1),
#  ('charging', 1),
#  ('car.', 1),
#  ('These', 1),
#  ('website,', 1),
#  ('them', 2),
#  ('keep...', 1),
#  ('Record-Low', 1),
#  ('Magic', 2),
#  ('Black', 3),
#  ('22,', 2),
#  ('1:15', 1),
#  ('Keyboard', 1),
#  ('best', 2),
#  ('White', 1),
#  ('$324.88,', 1),
#  ('24', 1),
#  ('Save', 1),
#  ('Duo', 1),
#  ('live', 1),
#  ('low', 2),
#  ('week', 2),
#  ('ago,', 1),
#  ('Friday.', 1),
#  ('17', 2),
#  ('Not', 1),
#  ('13?', 1),
#  ('Has', 1),
#  ('Official', 1),
#  ('$30', 1),
#  ('21,', 1),
#  ('Now', 1),
#  ('family', 1),
#  ('generation', 1),
#  ('seeing', 1),
#  ('Clear', 1),
#  ('Its', 1),
#  ('Discount,', 1),
#  ('Tablet', 1),
#  ('$459.99', 1),
#  ('($39', 1),
#  ('20,', 2),
#  ('Expercom', 1),
#  ('last', 1),
#  ('ever', 1),
#  ('tablet', 1),
#  ('colors', 1),
#  ('Purple', 1),
#  ('22', 1),
#  ('Exclusive', 1),
#  ('40%', 1),
#  ('again', 1),
#  ('bring', 1),
#  ('readers', 1),
#  ('earbuds,', 1),
#  ('markdown', 1),
#  ('($12', 1),
#  ('off)', 1),
#  ('exclusive', 1),
#  ('code.', 1),
#  ('with...', 1),
#  ('Archives', 1),
#  ('Older', 1),
#  ('Guides', 1),
#  ('Forums', 1),
#  ('Search', 1),
#  ('Vision', 1),
#  ('15', 4),
#  ('16iPhone', 1),
#  ('PromacOS', 1),
#  ('10MacBook', 1),
#  ('&', 1),
#  ('14Apple', 1),
#  ('TViPad', 1),
#  ('ProApple', 2),
#  ('2iPadAirPods', 1),
#  ('3Apple', 1),
#  ('Display', 1),
#  ('AiriPhone', 1),
#  ('13AirPods', 1),
#  ('MaxAirPods', 1),
#  ('Studio', 1),
#  ('SEMac', 2),
#  ('AiriPad', 1),
#  ('18Apple', 1),
#  ('17Apple', 1),
#  ('Pay', 1),
#  ('All', 1),
#  ('MacRumors', 19),
#  ('and', 53),
#  ('Blog:', 1),
#  ('Rumors', 2),
#  ('Deals:', 18),
#  ('Introduces', 2),
#  ('on', 23),
#  ('4K', 3),
#  ('($159)', 1),
#  ('AirPods', 8),
#  ('Max', 1),
#  ('($449)', 1),
#  ('Tuesday', 3),
#  ('October', 5),
#  ('5,', 1),
#  ('2021', 20),
#  ('PDT', 18),
#  ('by', 19),
#  ('Broussard', 18),
#  ('today', 10),
#  ('has', 7),
#  ('a', 67),
#  ('including', 2),
#  ('the', 42),
#  ('Max,', 1),
#  ('4K,', 1),
#  ('MacBook', 1),
#  ('Pro.', 1),
#  ('affiliate', 18),
#  ('partner', 18),
#  ('with', 22),
#  ('you', 25),
#  ('link', 15),
#  ('purchase,', 13),
#  ('receive', 12),
#  ('small', 11),
#  ('payment,', 9),
#  ('which', 11),
#  ('helps', 9),
#  ('keep', 8),
#  ('You', 2),
#  ('can', 7),
#  ('get', 5),
#  ('for', 22),
#  ('$159.00,', 1),
#  ('from', 10),
#  ('This', 7),
#  ('all-time', 3),
#  ('Read', 18),
#  ('Full', 18),
#  ('Article', 18),
#  ('11', 3),
#  ('Amazon', 13),
#  ('credit', 1),
#  ('spend', 1),
#  ('or', 3),
#  ('Card.', 1),
#  ('digital', 1),
#  ('will', 4),
#  ('be', 2),
#  ('delivered', 1),
#  ('to', 18),
#  ('email,', 1),
#  ('offer', 1),
#  ('automatically', 1),
#  ('some', 11),
#  ('Model,', 1),
#  ('$109', 1),
#  ('Regular', 1),
#  ('7:49', 1),
#  ("we're", 3),
#  ('sales', 2),
#  ('every', 1),
#  ('return', 1),
#  ('Wireless', 1),
#  ('Case', 1),
#  ('priced', 2),
#  ('$129.00,', 1),
#  ('$199.00.', 1),
#  ('also', 1),
#  ('find', 3),
#  ('Case,', 1),
#  ('Max.', 2),
#  ('13', 11),
#  ('Take', 2),
#  ('To', 1),
#  ('7:28', 1),
#  ('few', 1),
#  ('11-inch', 1),
#  ('configurations.', 1),
#  ('up', 3),
#  ('focuses', 1),
#  ('tablets', 1),
#  ("they're", 1),
#  ('all', 2),
#  ('available', 5),
#  ('Amazon.', 5),
#  ('site...', 2),
#  ('2', 1),
#  ('MagSafe', 10),
#  ('Battery', 4),
#  ('Pack', 2),
#  ('($15', 1),
#  ('September', 14),
#  ('30,', 2),
#  ('shared', 1),
#  ('discount', 3),
#  ('AT&T,', 1),
#  ('percent', 5),
#  ('off', 5),
#  ('Pack,', 1),
#  ('it', 1),
#  ('Today,', 1),
#  ("that's", 1),
#  ('changed,', 1),
#  ('order', 2),
#  ('$84.15,', 1),
#  ('$99.00.', 1),
#  ('20%', 2),
#  ("Hyper's", 2),
#  ('USB-C', 5),
#  ('Wall', 1),
#  ('Charger', 4),
#  ('8:18', 2),
#  ('pair', 2),
#  ('Satechi,', 1),
#  ('wall', 3),
#  ('later', 1),
#  ('while', 1),
#  ('one', 3),
#  ('week,', 3),
#  ('through', 1),
#  ('7.', 1),
#  ('small...', 1),
#  ('Taking', 1),
#  ('Wednesday', 3),
#  ('7:58', 1),
#  ('wide', 1),
#  ('selection', 1),
#  ('accessories,', 2),
#  ('Clear,', 1),
#  ('Silicone,', 2),
#  ('Leather', 1),
#  ('Cases', 3),
#  ('Sale', 2),
#  ('prices', 3),
#  ('been...', 1),
#  ('256GB', 2),
#  ('$649.99', 1),
#  ('10:05', 1),
#  ('$749.00.', 1),
#  ('Gold,', 1),
#  ('Silver,', 1),
#  ('Blue,', 1),
#  ('Gold', 2),
#  ('ship', 1),
#  ('same', 1),
#  ('sale...', 1),
#  ('3', 1),
#  ('Verizon', 3),
#  ('30%', 2),
#  ('Accessory', 1),
#  ('Bundles,', 1),
#  ('More', 3),
#  ('11:53', 1),
#  ('solid', 2),
#  ('discounts', 2),
#  ('case', 1),
#  ('screen', 1),
#  ('your', 3),
#  ('bundles,', 1),
#  ('more.', 2),
#  ('day', 3),
#  ('shipping', 1),
#  ('across', 1),
#  ('over', 1),
#  ('if', 1),
#  ("don't", 1),
#  ('link...', 1),
#  ('Chargers,', 1),
#  ('MagSafe-Compatible', 3),
#  ('8:39', 1),
#  ('taking', 1),
#  ('time', 2),
#  ('around,', 1),
#  ('MagSafe-compatible', 1),
#  ('payment,...', 2),
#  ('Virtual', 1),
#  ('HomePod', 1),
#  ('With', 1),
#  ('Visible', 2),
#  ('24,', 1),
#  ('launch', 2),
#  ('who', 1),
#  ("hasn't", 1),
#  ('pre-ordered', 1),
#  ('still', 2),
#  ('plenty', 1),
#  ('In', 1),
#  ('article', 1),
#  ('big', 1),
#  ('may...', 1),
#  ('64GB', 4),
#  ('First', 2),
#  ('Time', 1),
#  ('9:09', 1),
#  ('first', 3),
#  ('arrived', 1),
#  ('iPad,', 1),
#  ('is...', 1),
#  ('Bundle', 1),
#  ('Car', 3),
#  ('7:00', 1),
#  ('announced', 1),
#  ('release', 1),
#  ('aimed', 1),
#  ('devices', 3),
#  ('bundle', 1),
#  ('order.', 1),
#  ('Satechi.', 1),
#  ('35', 1),
#  ('Latest', 1),
#  ('12.9-Inch', 1),
#  ('Keyboard,', 1),
#  ('$324.88', 1),
#  ('pm', 1),
#  ('its', 2),
#  ('colors.', 1),
#  ('$349.00.', 1),
#  ('The...', 1),
#  ('Your', 2),
#  ('8:25', 1),
#  ('A', 1),
#  ('We', 1),
#  ('began', 1),
#  ("it's", 1),
#  ('great', 1),
#  ('buy', 1),
#  ('prices,', 1),
#  ('ahead', 1),
#  ('purchase,...', 1),
#  ('Upgrading', 1),
#  ('that', 2),
#  ('models', 1),
#  ('launching', 1),
#  ('previous', 1),
#  ('discounts.', 1),
#  ('On', 1),
#  ('Leather,', 1),
#  ('$13.99.', 1),
#  ('6', 1),
#  ('8:04', 1),
#  ('Following', 1),
#  ('footsteps', 1),
#  ('Walmart', 1),
#  ('mini', 1),
#  ('6.', 1),
#  ('except', 1),
#  ('$459.99,', 1),
#  ('$499.00.', 1),
#  ('Mount', 2),
#  ('Our', 1),
#  ('7:43', 1),
#  ("We've", 1),
#  ('partnered', 1),
#  ('our', 2),
#  ('coupon', 1),
#  ('codes', 1),
#  ('introduce', 1),
#  ('highlight', 1),
#  ('Magnetic', 1),
#  ('$17.99', 1),
#  ('Newer', 1),
#  ('Posts', 2),
#  ('ios', 1)]

# %%
rdd_sorted = count_rdd.map(lambda x: (x[1],x[0])).sortByKey()
rdd_sorted
# Out:
# Out[44]: PythonRDD[61] at RDD at PythonRDD.scala:58

# %%
first_ten = count_rdd.take(10)
for f in first_ten:
    print(f" : {f[0]} Value: {f[1]} ")
# Out:
#  :  Value: 20
#  : Site... Value: 1
#  : Apple Value: 10
#  : ProiOS Value: 1
#  : 17iPhone Value: 1
#  : 15iPhone Value: 1
#  : ProiPhone Value: 1
#  : 16 Value: 1
#  : SonomavisionOSwatchOS Value: 1
#  : Pro Value: 7

# %%
total_words = rdd_sorted.reduce(lambda a,b: (a[0]+b[0],a[1]))
print(f"Total Words : {total_words[0]} ")
# Out:
# Total Words : 1885

# %%
data = rdd.collect()
data
# Out:
# Out[47]: ['',
#  'Forums',
#  'Search Site...',
#  'Apple Vision ProiOS 17iPhone 15iPhone 15 ProiPhone 16iPhone 16 PromacOS SonomavisionOSwatchOS 10MacBook Pro 14 & 16"HomePodiPhone 14Apple TViPad ProApple Watch Ultra 2iPadAirPods 3Apple CarApple Pro Display XDRHomePod miniMac ProMacBook AiriPhone 13AirPods MaxAirPods ProApple DealsApple Studio DisplayApple Watch SEMac StudioiMaciPad AiriPad miniiPhone SEMac miniiOS 18Apple Watch Series 9CarPlayiPadOS 17Apple Pay',
#  'All >',
#  'MacRumors iPhone and iPad Blog: Apps, News, and Rumors',
#  'Apple News and Rumors',
#  '',
#  'Deals: Adorama Introduces New Low Prices on 32GB Apple TV 4K ($159) and AirPods Max ($449)',
#  'Tuesday October 5, 2021 7:27 am PDT by Mitchel Broussard',
#  'Adorama today has a collection of deals on select Apple products, including the AirPods Max, Apple TV 4K, and M1 MacBook Pro. Note: MacRumors is an affiliate partner with Adorama. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site running. Apple TV 4K You can get the 32GB Apple TV 4K for $159.00, down from $179.00. This is a new all-time ...',
#  'Read Full Article 11 comments',
#  '',
#  'Deals: Get $10 Amazon Credit When Purchasing a $100 Apple Gift Card',
#  'Monday October 4, 2021 8:52 am PDT by Mitchel Broussard',
#  'Amazon today is offering $10 in Amazon credit when you spend $100 or more on the Apple Gift Card. This card is digital and will be delivered to you via email, and the offer will automatically be applied at the checkout screen. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment, which helps us keep the...',
#  'Read Full Article 44 comments',
#  '',
#  'Deals: New Sales Hit Every AirPods Model, Starting at $109 for Regular AirPods',
#  'Monday October 4, 2021 7:49 am PDT by Mitchel Broussard',
#  "Today we're tracking new sales on every model of Apple's AirPods, starting with a return of the lowest-ever price on the AirPods with Wireless Charging Case on Amazon, priced at $129.00, down from $199.00. Below you'll also find sales on the AirPods with Wired Charging Case, AirPods Pro, and AirPods Max. Note: MacRumors is an affiliate partner with these vendors. When you click a link and make ...",
#  'Read Full Article 13 comments',
#  '',
#  'Deals: Take Up To $100 Off 2021 iPad Pro Tablets at Amazon',
#  'Friday October 1, 2021 7:28 am PDT by Mitchel Broussard',
#  "Amazon today has a few deals on the 2021 iPad Pro in both 11-inch and 12.9-inch configurations. You'll have a chance to save up to $100 on these models, and this sale focuses on Wi-Fi only tablets and they're all available on Amazon. Note: MacRumors is an affiliate partner with Amazon. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site...",
#  'Read Full Article 2 comments',
#  '',
#  "Deals: Apple's MagSafe Battery Pack Drops to $84.15 ($15 Off)",
#  'Thursday September 30, 2021 11:22 am PDT by Mitchel Broussard',
#  "Yesterday we shared a new discount event happening at AT&T, where you can get 15 percent off select Apple accessories this fall. One notable accessory in the sale was the MagSafe Battery Pack, but it was out of stock. Today, however, that's changed, and you can now order the MagSafe Battery Pack for $84.15, down from $99.00. Note: MacRumors is an affiliate partner with some of these vendors....",
#  'Read Full Article 19 comments',
#  '',
#  "Deals: Get 20% Off Hyper's 18W Battery Packs and Satechi's 100W USB-C Wall Charger",
#  'Thursday September 30, 2021 8:18 am PDT by Mitchel Broussard',
#  "Today we have a pair of charging-related deals from Hyper and Satechi, which are offering 20 percent off a portable battery and USB-C wall charger, respectively. Hyper's sale will end later today, while Satechi's will run for one week, through October 7. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small...",
#  'Read Full Article 12 comments',
#  '',
#  "Deals: AT&T Taking 15% Off Apple's MagSafe Accessories",
#  'Wednesday September 29, 2021 7:58 am PDT by Mitchel Broussard',
#  "Today at AT&T you can get 15 percent off a wide selection of Apple's MagSafe accessories, including Clear, Silicone, and Leather Cases for the iPhone 13, 13 mini, 13 Pro, and 13 Pro Max. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site running. Sale prices have been...",
#  'Read Full Article 13 comments',
#  '',
#  "Deals: Get Apple's 256GB Wi-Fi iPad Air for $649.99 ($99 Off)",
#  'Tuesday September 28, 2021 10:05 am PDT by Mitchel Broussard',
#  'Amazon today has the 256GB iPad Air for $649.99, down from $749.00. This sale price is available in Rose Gold, Silver, Sky Blue, and Space Gray, but only Rose Gold is available to ship out today. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site running. This same sale...',
#  'Read Full Article 3 comments',
#  '',
#  'Deals: Verizon Offering Up to 30% Off MagSafe Accessory Bundles, iPhone 13 Cases, and More',
#  'Monday September 27, 2021 11:53 am PDT by Mitchel Broussard',
#  "Today we're tracking a handful of solid accessory discounts offered by Verizon, offering a chance to save on a new case or screen protector for your iPhone 13, MagSafe bundles, and more. Verizon offers free two day shipping across the board on orders over $49, even if you don't use Verizon as a carrier. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link...",
#  'Read Full Article 10 comments',
#  '',
#  "Deals: Get Up to 45% Off Anker's USB-C Chargers, MagSafe-Compatible Accessories, and More",
#  'Monday September 27, 2021 8:39 am PDT by Mitchel Broussard',
#  'Anker today introduced a new Gold Box sale on Amazon, taking up to 45 percent off select accessories for one day only. This time around, the deals include savings on USB-C wall chargers, portable batteries, and MagSafe-compatible wireless chargers. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment,...',
#  'Read Full Article 12 comments',
#  '',
#  'Deals: Get a $200 Virtual Gift Card and Free HomePod Mini With Purchase of iPhone 13 at Visible',
#  'Friday September 24, 2021 7:19 am PDT by Mitchel Broussard',
#  "It's iPhone 13 launch day today, and anyone who hasn't pre-ordered the smartphone still has plenty of options to purchase the new iPhone. In this article we're highlighting a deal from Verizon-owned Visible Wireless, which is a low-cost alternative to the big name carriers. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may...",
#  'Read Full Article 12 comments',
#  '',
#  'Deals: Amazon Drops Price of New 64GB Wi-Fi iPad to $299.00 for the First Time ($30 Off)',
#  'Thursday September 23, 2021 9:09 am PDT by Mitchel Broussard',
#  'The first Amazon discount has arrived today for the new 10.2-inch iPad, and you can get the 64GB Wi-Fi model for $299.00, down from $329.00. This price is only available in Space Gray on Amazon. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site running. This sale is...',
#  'Read Full Article 12 comments',
#  '',
#  "Deals: Take 20% Off a Bundle of Satechi's New MagSafe-Compatible and Dual USB-C Car Chargers",
#  'Thursday September 23, 2021 7:00 am PDT by Mitchel Broussard',
#  "Satechi today announced the release of a trio of new accessories, aimed at charging up an iPhone in your car. These devices are available to order today on Satechi's website, and when you bundle two of them you can save 20 percent off your order. Note: MacRumors is an affiliate partner with Satechi. When you click a link and make a purchase, we may receive a small payment, which helps us keep...",
#  'Read Full Article 35 comments',
#  '',
#  "Deals: Record-Low Prices Hit Apple's Latest 12.9-Inch iPad Pro Magic Keyboard, Starting at $324.88 for Black",
#  'Wednesday September 22, 2021 1:15 pm PDT by Mitchel Broussard',
#  "Amazon today has Apple's Magic Keyboard for the 12.9-inch iPad Pro at its all-time best prices in both Black and White colors. You can get the Black model of the accessory for $324.88, down from $349.00. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site running. The...",
#  'Read Full Article 24 comments',
#  '',
#  "Deals: Save Up to 30% on Apple's MagSafe Charger Accessories for Your iPhone 12 or iPhone 13",
#  'Wednesday September 22, 2021 8:25 am PDT by Mitchel Broussard',
#  "A pair of solid deals on Apple's MagSafe Charger and MagSafe Duo Charger are still live at Amazon and Verizon, respectively. We first began tracking these all-time low prices one week ago, and it's a great time to buy them now at these prices, ahead of the iPhone 13 launch on Friday. Note: MacRumors is an affiliate partner with some of these vendors. When you click a link and make a purchase,...",
#  'Read Full Article 17 comments',
#  '',
#  "Deals: Not Upgrading to iPhone 13? Amazon Has Apple's Official iPhone 11 and iPhone 12 Cases for Up to $30 Off",
#  'Tuesday September 21, 2021 8:18 am PDT by Mitchel Broussard',
#  "Now that a new family of iPhone models are launching this week, accessories for the previous generation devices are seeing notable discounts. On Amazon, you'll find Silicone, Leather, and Clear Cases for the iPhone 12 and iPhone 11 devices starting as low as $13.99. Note: MacRumors is an affiliate partner with Amazon. When you click a link and make a purchase, we may receive a small payment,...",
#  'Read Full Article 15 comments',
#  '',
#  'Deals: Amazon Introduces Its First iPad Mini 6 Discount, Get the 64GB Wi-Fi Tablet for $459.99 ($39 Off)',
#  'Monday September 20, 2021 8:04 am PDT by Mitchel Broussard',
#  "Following in the footsteps of Expercom and Walmart from last week, Amazon today has introduced its first ever discount on the new iPad mini 6. You'll find the 64GB Wi-Fi tablet in all colors except Purple at $459.99, down from $499.00. Note: MacRumors is an affiliate partner with Amazon. When you click a link and make a purchase, we may receive a small payment, which helps us keep the site...",
#  'Read Full Article 22 comments',
#  '',
#  'Exclusive Deals: Get 40% Off a MagSafe-Compatible Car Mount for Your iPhone 13 and More in Our New Anker Sale',
#  'Monday September 20, 2021 7:43 am PDT by Mitchel Broussard',
#  "We've partnered with Anker again this week to bring our readers a collection of coupon codes that introduce notable discounts on Anker's best wall chargers, portable chargers, earbuds, and more. The highlight of the sale is a markdown on the Anker Magnetic Car Mount for iPhone 12 and iPhone 13, priced at $17.99 ($12 off) with our exclusive code. Note: MacRumors is an affiliate partner with...",
#  'Read Full Article 20 comments',
#  'Newer Posts',
#  'Archives',
#  'Older Posts',
#  'Guides',
#  'ios 17 ']

# %%
import re
pattern = r'[\n\s!@#$%^&*\(\)\{\}\[\]~`/\?<>,\.]+'
words = re.split(pattern, str(data))
words
# Out:
# Out[48]: ['',
#  "''",
#  "'Forums'",
#  "'Search",
#  'Site',
#  "'",
#  "'Apple",
#  'Vision',
#  'ProiOS',
#  '17iPhone',
#  '15iPhone',
#  '15',
#  'ProiPhone',
#  '16iPhone',
#  '16',
#  'PromacOS',
#  'SonomavisionOSwatchOS',
#  '10MacBook',
#  'Pro',
#  '14',
#  '16"HomePodiPhone',
#  '14Apple',
#  'TViPad',
#  'ProApple',
#  'Watch',
#  'Ultra',
#  '2iPadAirPods',
#  '3Apple',
#  'CarApple',
#  'Pro',
#  'Display',
#  'XDRHomePod',
#  'miniMac',
#  'ProMacBook',
#  'AiriPhone',
#  '13AirPods',
#  'MaxAirPods',
#  'ProApple',
#  'DealsApple',
#  'Studio',
#  'DisplayApple',
#  'Watch',
#  'SEMac',
#  'StudioiMaciPad',
#  'AiriPad',
#  'miniiPhone',
#  'SEMac',
#  'miniiOS',
#  '18Apple',
#  'Watch',
#  'Series',
#  '9CarPlayiPadOS',
#  '17Apple',
#  "Pay'",
#  "'All",
#  "'",
#  "'MacRumors",
#  'iPhone',
#  'and',
#  'iPad',
#  'Blog:',
#  'Apps',
#  'News',
#  'and',
#  "Rumors'",
#  "'Apple",
#  'News',
#  'and',
#  "Rumors'",
#  "''",
#  "'Deals:",
#  'Adorama',
#  'Introduces',
#  'New',
#  'Low',
#  'Prices',
#  'on',
#  '32GB',
#  'Apple',
#  'TV',
#  '4K',
#  '159',
#  'and',
#  'AirPods',
#  'Max',
#  '449',
#  "'",
#  "'Tuesday",
#  'October',
#  '5',
#  '2021',
#  '7:27',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  "Broussard'",
#  "'Adorama",
#  'today',
#  'has',
#  'a',
#  'collection',
#  'of',
#  'deals',
#  'on',
#  'select',
#  'Apple',
#  'products',
#  'including',
#  'the',
#  'AirPods',
#  'Max',
#  'Apple',
#  'TV',
#  '4K',
#  'and',
#  'M1',
#  'MacBook',
#  'Pro',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'Adorama',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  'payment',
#  'which',
#  'helps',
#  'us',
#  'keep',
#  'the',
#  'site',
#  'running',
#  'Apple',
#  'TV',
#  '4K',
#  'You',
#  'can',
#  'get',
#  'the',
#  '32GB',
#  'Apple',
#  'TV',
#  '4K',
#  'for',
#  '159',
#  '00',
#  'down',
#  'from',
#  '179',
#  '00',
#  'This',
#  'is',
#  'a',
#  'new',
#  'all-time',
#  "'",
#  "'Read",
#  'Full',
#  'Article',
#  '11',
#  "comments'",
#  "''",
#  "'Deals:",
#  'Get',
#  '10',
#  'Amazon',
#  'Credit',
#  'When',
#  'Purchasing',
#  'a',
#  '100',
#  'Apple',
#  'Gift',
#  "Card'",
#  "'Monday",
#  'October',
#  '4',
#  '2021',
#  '8:52',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  "Broussard'",
#  "'Amazon",
#  'today',
#  'is',
#  'offering',
#  '10',
#  'in',
#  'Amazon',
#  'credit',
#  'when',
#  'you',
#  'spend',
#  '100',
#  'or',
#  'more',
#  'on',
#  'the',
#  'Apple',
#  'Gift',
#  'Card',
#  'This',
#  'card',
#  'is',
#  'digital',
#  'and',
#  'will',
#  'be',
#  'delivered',
#  'to',
#  'you',
#  'via',
#  'email',
#  'and',
#  'the',
#  'offer',
#  'will',
#  'automatically',
#  'be',
#  'applied',
#  'at',
#  'the',
#  'checkout',
#  'screen',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  'payment',
#  'which',
#  'helps',
#  'us',
#  'keep',
#  'the',
#  "'",
#  "'Read",
#  'Full',
#  'Article',
#  '44',
#  "comments'",
#  "''",
#  "'Deals:",
#  'New',
#  'Sales',
#  'Hit',
#  'Every',
#  'AirPods',
#  'Model',
#  'Starting',
#  'at',
#  '109',
#  'for',
#  'Regular',
#  "AirPods'",
#  "'Monday",
#  'October',
#  '4',
#  '2021',
#  '7:49',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  "Broussard'",
#  '"Today',
#  "we're",
#  'tracking',
#  'new',
#  'sales',
#  'on',
#  'every',
#  'model',
#  'of',
#  "Apple's",
#  'AirPods',
#  'starting',
#  'with',
#  'a',
#  'return',
#  'of',
#  'the',
#  'lowest-ever',
#  'price',
#  'on',
#  'the',
#  'AirPods',
#  'with',
#  'Wireless',
#  'Charging',
#  'Case',
#  'on',
#  'Amazon',
#  'priced',
#  'at',
#  '129',
#  '00',
#  'down',
#  'from',
#  '199',
#  '00',
#  'Below',
#  "you'll",
#  'also',
#  'find',
#  'sales',
#  'on',
#  'the',
#  'AirPods',
#  'with',
#  'Wired',
#  'Charging',
#  'Case',
#  'AirPods',
#  'Pro',
#  'and',
#  'AirPods',
#  'Max',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'these',
#  'vendors',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  '"',
#  "'Read",
#  'Full',
#  'Article',
#  '13',
#  "comments'",
#  "''",
#  "'Deals:",
#  'Take',
#  'Up',
#  'To',
#  '100',
#  'Off',
#  '2021',
#  'iPad',
#  'Pro',
#  'Tablets',
#  'at',
#  "Amazon'",
#  "'Friday",
#  'October',
#  '1',
#  '2021',
#  '7:28',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  "Broussard'",
#  '"Amazon',
#  'today',
#  'has',
#  'a',
#  'few',
#  'deals',
#  'on',
#  'the',
#  '2021',
#  'iPad',
#  'Pro',
#  'in',
#  'both',
#  '11-inch',
#  'and',
#  '12',
#  '9-inch',
#  'configurations',
#  "You'll",
#  'have',
#  'a',
#  'chance',
#  'to',
#  'save',
#  'up',
#  'to',
#  '100',
#  'on',
#  'these',
#  'models',
#  'and',
#  'this',
#  'sale',
#  'focuses',
#  'on',
#  'Wi-Fi',
#  'only',
#  'tablets',
#  'and',
#  "they're",
#  'all',
#  'available',
#  'on',
#  'Amazon',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'Amazon',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  'payment',
#  'which',
#  'helps',
#  'us',
#  'keep',
#  'the',
#  'site',
#  '"',
#  "'Read",
#  'Full',
#  'Article',
#  '2',
#  "comments'",
#  "''",
#  '"Deals:',
#  "Apple's",
#  'MagSafe',
#  'Battery',
#  'Pack',
#  'Drops',
#  'to',
#  '84',
#  '15',
#  '15',
#  'Off',
#  '"',
#  "'Thursday",
#  'September',
#  '30',
#  '2021',
#  '11:22',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  "Broussard'",
#  '"Yesterday',
#  'we',
#  'shared',
#  'a',
#  'new',
#  'discount',
#  'event',
#  'happening',
#  'at',
#  'AT',
#  'T',
#  'where',
#  'you',
#  'can',
#  'get',
#  '15',
#  'percent',
#  'off',
#  'select',
#  'Apple',
#  'accessories',
#  'this',
#  'fall',
#  'One',
#  'notable',
#  'accessory',
#  'in',
#  'the',
#  'sale',
#  'was',
#  'the',
#  'MagSafe',
#  'Battery',
#  'Pack',
#  'but',
#  'it',
#  'was',
#  'out',
#  'of',
#  'stock',
#  'Today',
#  'however',
#  "that's",
#  'changed',
#  'and',
#  'you',
#  'can',
#  'now',
#  'order',
#  'the',
#  'MagSafe',
#  'Battery',
#  'Pack',
#  'for',
#  '84',
#  '15',
#  'down',
#  'from',
#  '99',
#  '00',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors',
#  '"',
#  "'Read",
#  'Full',
#  'Article',
#  '19',
#  "comments'",
#  "''",
#  '"Deals:',
#  'Get',
#  '20',
#  'Off',
#  "Hyper's",
#  '18W',
#  'Battery',
#  'Packs',
#  'and',
#  "Satechi's",
#  '100W',
#  'USB-C',
#  'Wall',
#  'Charger"',
#  "'Thursday",
#  'September',
#  '30',
#  '2021',
#  '8:18',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  "Broussard'",
#  '"Today',
#  'we',
#  'have',
#  'a',
#  'pair',
#  'of',
#  'charging-related',
#  'deals',
#  'from',
#  'Hyper',
#  'and',
#  'Satechi',
#  'which',
#  'are',
#  'offering',
#  '20',
#  'percent',
#  'off',
#  'a',
#  'portable',
#  'battery',
#  'and',
#  'USB-C',
#  'wall',
#  'charger',
#  'respectively',
#  "Hyper's",
#  'sale',
#  'will',
#  'end',
#  'later',
#  'today',
#  'while',
#  "Satechi's",
#  'will',
#  'run',
#  'for',
#  'one',
#  'week',
#  'through',
#  'October',
#  '7',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  '"',
#  "'Read",
#  'Full',
#  'Article',
#  '12',
#  "comments'",
#  "''",
#  '"Deals:',
#  'AT',
#  'T',
#  'Taking',
#  '15',
#  'Off',
#  "Apple's",
#  'MagSafe',
#  'Accessories"',
#  "'Wednesday",
#  'September',
#  '29',
#  '2021',
#  '7:58',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  "Broussard'",
#  '"Today',
#  'at',
#  'AT',
#  'T',
#  'you',
#  'can',
#  'get',
#  '15',
#  'percent',
#  'off',
#  'a',
#  'wide',
#  'selection',
#  'of',
#  "Apple's",
#  'MagSafe',
#  'accessories',
#  'including',
#  'Clear',
#  'Silicone',
#  'and',
#  'Leather',
#  'Cases',
#  'for',
#  'the',
#  'iPhone',
#  '13',
#  '13',
#  'mini',
#  '13',
#  'Pro',
#  'and',
#  '13',
#  'Pro',
#  'Max',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  'payment',
#  'which',
#  'helps',
#  'us',
#  'keep',
#  'the',
#  'site',
#  'running',
#  'Sale',
#  'prices',
#  'have',
#  'been',
#  '"',
#  "'Read",
#  'Full',
#  'Article',
#  '13',
#  "comments'",
#  "''",
#  '"Deals:',
#  'Get',
#  "Apple's",
#  '256GB',
#  'Wi-Fi',
#  'iPad',
#  'Air',
#  'for',
#  '649',
#  '99',
#  '99',
#  'Off',
#  '"',
#  "'Tuesday",
#  'September',
#  '28',
#  '2021',
#  '10:05',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  "Broussard'",
#  "'Amazon",
#  'today',
#  'has',
#  'the',
#  '256GB',
#  'iPad',
#  'Air',
#  'for',
#  '649',
#  '99',
#  'down',
#  'from',
#  '749',
#  '00',
#  'This',
#  'sale',
#  'price',
#  'is',
#  'available',
#  'in',
#  'Rose',
#  'Gold',
#  'Silver',
#  'Sky',
#  'Blue',
#  'and',
#  'Space',
#  'Gray',
#  'but',
#  'only',
#  'Rose',
#  'Gold',
#  'is',
#  'available',
#  'to',
#  'ship',
#  'out',
#  'today',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  'and',
#  'make',
#  'a',
#  'purchase',
#  'we',
#  'may',
#  'receive',
#  'a',
#  'small',
#  'payment',
#  'which',
#  'helps',
#  'us',
#  'keep',
#  'the',
#  'site',
#  'running',
#  'This',
#  'same',
#  'sale',
#  "'",
#  "'Read",
#  'Full',
#  'Article',
#  '3',
#  "comments'",
#  "''",
#  "'Deals:",
#  'Verizon',
#  'Offering',
#  'Up',
#  'to',
#  '30',
#  'Off',
#  'MagSafe',
#  'Accessory',
#  'Bundles',
#  'iPhone',
#  '13',
#  'Cases',
#  'and',
#  "More'",
#  "'Monday",
#  'September',
#  '27',
#  '2021',
#  '11:53',
#  'am',
#  'PDT',
#  'by',
#  'Mitchel',
#  "Broussard'",
#  '"Today',
#  "we're",
#  'tracking',
#  'a',
#  'handful',
#  'of',
#  'solid',
#  'accessory',
#  'discounts',
#  'offered',
#  'by',
#  'Verizon',
#  'offering',
#  'a',
#  'chance',
#  'to',
#  'save',
#  'on',
#  'a',
#  'new',
#  'case',
#  'or',
#  'screen',
#  'protector',
#  'for',
#  'your',
#  'iPhone',
#  '13',
#  'MagSafe',
#  'bundles',
#  'and',
#  'more',
#  'Verizon',
#  'offers',
#  'free',
#  'two',
#  'day',
#  'shipping',
#  'across',
#  'the',
#  'board',
#  'on',
#  'orders',
#  'over',
#  '49',
#  'even',
#  'if',
#  'you',
#  "don't",
#  'use',
#  'Verizon',
#  'as',
#  'a',
#  'carrier',
#  'Note:',
#  'MacRumors',
#  'is',
#  'an',
#  'affiliate',
#  'partner',
#  'with',
#  'some',
#  'of',
#  'these',
#  'vendors',
#  'When',
#  'you',
#  'click',
#  'a',
#  'link',
#  '"',
#  "'Read",
#  'Full',
#  'Article',
#  '10',
#  "comments'",
#  "''",
#  '"Deals:',
#  'Get',
#  'Up',
#  'to',
#  '45',
#  'Off',
#  "Anker's",
#  'USB-C',
#  'Chargers',
#  'MagSafe-Compatible',
#  'Accessories',
#  'and',
#  'More"',
#  "'Monday",
#  'September',
#  '27',
#  ...]

# %%
word_count = list(map(lambda x: (x, 1), words))
word_count
# Out:
# Out[49]: [('', 1),
#  ("''", 1),
#  ("'Forums'", 1),
#  ("'Search", 1),
#  ('Site', 1),
#  ("'", 1),
#  ("'Apple", 1),
#  ('Vision', 1),
#  ('ProiOS', 1),
#  ('17iPhone', 1),
#  ('15iPhone', 1),
#  ('15', 1),
#  ('ProiPhone', 1),
#  ('16iPhone', 1),
#  ('16', 1),
#  ('PromacOS', 1),
#  ('SonomavisionOSwatchOS', 1),
#  ('10MacBook', 1),
#  ('Pro', 1),
#  ('14', 1),
#  ('16"HomePodiPhone', 1),
#  ('14Apple', 1),
#  ('TViPad', 1),
#  ('ProApple', 1),
#  ('Watch', 1),
#  ('Ultra', 1),
#  ('2iPadAirPods', 1),
#  ('3Apple', 1),
#  ('CarApple', 1),
#  ('Pro', 1),
#  ('Display', 1),
#  ('XDRHomePod', 1),
#  ('miniMac', 1),
#  ('ProMacBook', 1),
#  ('AiriPhone', 1),
#  ('13AirPods', 1),
#  ('MaxAirPods', 1),
#  ('ProApple', 1),
#  ('DealsApple', 1),
#  ('Studio', 1),
#  ('DisplayApple', 1),
#  ('Watch', 1),
#  ('SEMac', 1),
#  ('StudioiMaciPad', 1),
#  ('AiriPad', 1),
#  ('miniiPhone', 1),
#  ('SEMac', 1),
#  ('miniiOS', 1),
#  ('18Apple', 1),
#  ('Watch', 1),
#  ('Series', 1),
#  ('9CarPlayiPadOS', 1),
#  ('17Apple', 1),
#  ("Pay'", 1),
#  ("'All", 1),
#  ("'", 1),
#  ("'MacRumors", 1),
#  ('iPhone', 1),
#  ('and', 1),
#  ('iPad', 1),
#  ('Blog:', 1),
#  ('Apps', 1),
#  ('News', 1),
#  ('and', 1),
#  ("Rumors'", 1),
#  ("'Apple", 1),
#  ('News', 1),
#  ('and', 1),
#  ("Rumors'", 1),
#  ("''", 1),
#  ("'Deals:", 1),
#  ('Adorama', 1),
#  ('Introduces', 1),
#  ('New', 1),
#  ('Low', 1),
#  ('Prices', 1),
#  ('on', 1),
#  ('32GB', 1),
#  ('Apple', 1),
#  ('TV', 1),
#  ('4K', 1),
#  ('159', 1),
#  ('and', 1),
#  ('AirPods', 1),
#  ('Max', 1),
#  ('449', 1),
#  ("'", 1),
#  ("'Tuesday", 1),
#  ('October', 1),
#  ('5', 1),
#  ('2021', 1),
#  ('7:27', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ("Broussard'", 1),
#  ("'Adorama", 1),
#  ('today', 1),
#  ('has', 1),
#  ('a', 1),
#  ('collection', 1),
#  ('of', 1),
#  ('deals', 1),
#  ('on', 1),
#  ('select', 1),
#  ('Apple', 1),
#  ('products', 1),
#  ('including', 1),
#  ('the', 1),
#  ('AirPods', 1),
#  ('Max', 1),
#  ('Apple', 1),
#  ('TV', 1),
#  ('4K', 1),
#  ('and', 1),
#  ('M1', 1),
#  ('MacBook', 1),
#  ('Pro', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('Adorama', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('payment', 1),
#  ('which', 1),
#  ('helps', 1),
#  ('us', 1),
#  ('keep', 1),
#  ('the', 1),
#  ('site', 1),
#  ('running', 1),
#  ('Apple', 1),
#  ('TV', 1),
#  ('4K', 1),
#  ('You', 1),
#  ('can', 1),
#  ('get', 1),
#  ('the', 1),
#  ('32GB', 1),
#  ('Apple', 1),
#  ('TV', 1),
#  ('4K', 1),
#  ('for', 1),
#  ('159', 1),
#  ('00', 1),
#  ('down', 1),
#  ('from', 1),
#  ('179', 1),
#  ('00', 1),
#  ('This', 1),
#  ('is', 1),
#  ('a', 1),
#  ('new', 1),
#  ('all-time', 1),
#  ("'", 1),
#  ("'Read", 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('11', 1),
#  ("comments'", 1),
#  ("''", 1),
#  ("'Deals:", 1),
#  ('Get', 1),
#  ('10', 1),
#  ('Amazon', 1),
#  ('Credit', 1),
#  ('When', 1),
#  ('Purchasing', 1),
#  ('a', 1),
#  ('100', 1),
#  ('Apple', 1),
#  ('Gift', 1),
#  ("Card'", 1),
#  ("'Monday", 1),
#  ('October', 1),
#  ('4', 1),
#  ('2021', 1),
#  ('8:52', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ("Broussard'", 1),
#  ("'Amazon", 1),
#  ('today', 1),
#  ('is', 1),
#  ('offering', 1),
#  ('10', 1),
#  ('in', 1),
#  ('Amazon', 1),
#  ('credit', 1),
#  ('when', 1),
#  ('you', 1),
#  ('spend', 1),
#  ('100', 1),
#  ('or', 1),
#  ('more', 1),
#  ('on', 1),
#  ('the', 1),
#  ('Apple', 1),
#  ('Gift', 1),
#  ('Card', 1),
#  ('This', 1),
#  ('card', 1),
#  ('is', 1),
#  ('digital', 1),
#  ('and', 1),
#  ('will', 1),
#  ('be', 1),
#  ('delivered', 1),
#  ('to', 1),
#  ('you', 1),
#  ('via', 1),
#  ('email', 1),
#  ('and', 1),
#  ('the', 1),
#  ('offer', 1),
#  ('will', 1),
#  ('automatically', 1),
#  ('be', 1),
#  ('applied', 1),
#  ('at', 1),
#  ('the', 1),
#  ('checkout', 1),
#  ('screen', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('payment', 1),
#  ('which', 1),
#  ('helps', 1),
#  ('us', 1),
#  ('keep', 1),
#  ('the', 1),
#  ("'", 1),
#  ("'Read", 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('44', 1),
#  ("comments'", 1),
#  ("''", 1),
#  ("'Deals:", 1),
#  ('New', 1),
#  ('Sales', 1),
#  ('Hit', 1),
#  ('Every', 1),
#  ('AirPods', 1),
#  ('Model', 1),
#  ('Starting', 1),
#  ('at', 1),
#  ('109', 1),
#  ('for', 1),
#  ('Regular', 1),
#  ("AirPods'", 1),
#  ("'Monday", 1),
#  ('October', 1),
#  ('4', 1),
#  ('2021', 1),
#  ('7:49', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ("Broussard'", 1),
#  ('"Today', 1),
#  ("we're", 1),
#  ('tracking', 1),
#  ('new', 1),
#  ('sales', 1),
#  ('on', 1),
#  ('every', 1),
#  ('model', 1),
#  ('of', 1),
#  ("Apple's", 1),
#  ('AirPods', 1),
#  ('starting', 1),
#  ('with', 1),
#  ('a', 1),
#  ('return', 1),
#  ('of', 1),
#  ('the', 1),
#  ('lowest-ever', 1),
#  ('price', 1),
#  ('on', 1),
#  ('the', 1),
#  ('AirPods', 1),
#  ('with', 1),
#  ('Wireless', 1),
#  ('Charging', 1),
#  ('Case', 1),
#  ('on', 1),
#  ('Amazon', 1),
#  ('priced', 1),
#  ('at', 1),
#  ('129', 1),
#  ('00', 1),
#  ('down', 1),
#  ('from', 1),
#  ('199', 1),
#  ('00', 1),
#  ('Below', 1),
#  ("you'll", 1),
#  ('also', 1),
#  ('find', 1),
#  ('sales', 1),
#  ('on', 1),
#  ('the', 1),
#  ('AirPods', 1),
#  ('with', 1),
#  ('Wired', 1),
#  ('Charging', 1),
#  ('Case', 1),
#  ('AirPods', 1),
#  ('Pro', 1),
#  ('and', 1),
#  ('AirPods', 1),
#  ('Max', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('these', 1),
#  ('vendors', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('"', 1),
#  ("'Read", 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('13', 1),
#  ("comments'", 1),
#  ("''", 1),
#  ("'Deals:", 1),
#  ('Take', 1),
#  ('Up', 1),
#  ('To', 1),
#  ('100', 1),
#  ('Off', 1),
#  ('2021', 1),
#  ('iPad', 1),
#  ('Pro', 1),
#  ('Tablets', 1),
#  ('at', 1),
#  ("Amazon'", 1),
#  ("'Friday", 1),
#  ('October', 1),
#  ('1', 1),
#  ('2021', 1),
#  ('7:28', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ("Broussard'", 1),
#  ('"Amazon', 1),
#  ('today', 1),
#  ('has', 1),
#  ('a', 1),
#  ('few', 1),
#  ('deals', 1),
#  ('on', 1),
#  ('the', 1),
#  ('2021', 1),
#  ('iPad', 1),
#  ('Pro', 1),
#  ('in', 1),
#  ('both', 1),
#  ('11-inch', 1),
#  ('and', 1),
#  ('12', 1),
#  ('9-inch', 1),
#  ('configurations', 1),
#  ("You'll", 1),
#  ('have', 1),
#  ('a', 1),
#  ('chance', 1),
#  ('to', 1),
#  ('save', 1),
#  ('up', 1),
#  ('to', 1),
#  ('100', 1),
#  ('on', 1),
#  ('these', 1),
#  ('models', 1),
#  ('and', 1),
#  ('this', 1),
#  ('sale', 1),
#  ('focuses', 1),
#  ('on', 1),
#  ('Wi-Fi', 1),
#  ('only', 1),
#  ('tablets', 1),
#  ('and', 1),
#  ("they're", 1),
#  ('all', 1),
#  ('available', 1),
#  ('on', 1),
#  ('Amazon', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('Amazon', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('payment', 1),
#  ('which', 1),
#  ('helps', 1),
#  ('us', 1),
#  ('keep', 1),
#  ('the', 1),
#  ('site', 1),
#  ('"', 1),
#  ("'Read", 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('2', 1),
#  ("comments'", 1),
#  ("''", 1),
#  ('"Deals:', 1),
#  ("Apple's", 1),
#  ('MagSafe', 1),
#  ('Battery', 1),
#  ('Pack', 1),
#  ('Drops', 1),
#  ('to', 1),
#  ('84', 1),
#  ('15', 1),
#  ('15', 1),
#  ('Off', 1),
#  ('"', 1),
#  ("'Thursday", 1),
#  ('September', 1),
#  ('30', 1),
#  ('2021', 1),
#  ('11:22', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ("Broussard'", 1),
#  ('"Yesterday', 1),
#  ('we', 1),
#  ('shared', 1),
#  ('a', 1),
#  ('new', 1),
#  ('discount', 1),
#  ('event', 1),
#  ('happening', 1),
#  ('at', 1),
#  ('AT', 1),
#  ('T', 1),
#  ('where', 1),
#  ('you', 1),
#  ('can', 1),
#  ('get', 1),
#  ('15', 1),
#  ('percent', 1),
#  ('off', 1),
#  ('select', 1),
#  ('Apple', 1),
#  ('accessories', 1),
#  ('this', 1),
#  ('fall', 1),
#  ('One', 1),
#  ('notable', 1),
#  ('accessory', 1),
#  ('in', 1),
#  ('the', 1),
#  ('sale', 1),
#  ('was', 1),
#  ('the', 1),
#  ('MagSafe', 1),
#  ('Battery', 1),
#  ('Pack', 1),
#  ('but', 1),
#  ('it', 1),
#  ('was', 1),
#  ('out', 1),
#  ('of', 1),
#  ('stock', 1),
#  ('Today', 1),
#  ('however', 1),
#  ("that's", 1),
#  ('changed', 1),
#  ('and', 1),
#  ('you', 1),
#  ('can', 1),
#  ('now', 1),
#  ('order', 1),
#  ('the', 1),
#  ('MagSafe', 1),
#  ('Battery', 1),
#  ('Pack', 1),
#  ('for', 1),
#  ('84', 1),
#  ('15', 1),
#  ('down', 1),
#  ('from', 1),
#  ('99', 1),
#  ('00', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors', 1),
#  ('"', 1),
#  ("'Read", 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('19', 1),
#  ("comments'", 1),
#  ("''", 1),
#  ('"Deals:', 1),
#  ('Get', 1),
#  ('20', 1),
#  ('Off', 1),
#  ("Hyper's", 1),
#  ('18W', 1),
#  ('Battery', 1),
#  ('Packs', 1),
#  ('and', 1),
#  ("Satechi's", 1),
#  ('100W', 1),
#  ('USB-C', 1),
#  ('Wall', 1),
#  ('Charger"', 1),
#  ("'Thursday", 1),
#  ('September', 1),
#  ('30', 1),
#  ('2021', 1),
#  ('8:18', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ("Broussard'", 1),
#  ('"Today', 1),
#  ('we', 1),
#  ('have', 1),
#  ('a', 1),
#  ('pair', 1),
#  ('of', 1),
#  ('charging-related', 1),
#  ('deals', 1),
#  ('from', 1),
#  ('Hyper', 1),
#  ('and', 1),
#  ('Satechi', 1),
#  ('which', 1),
#  ('are', 1),
#  ('offering', 1),
#  ('20', 1),
#  ('percent', 1),
#  ('off', 1),
#  ('a', 1),
#  ('portable', 1),
#  ('battery', 1),
#  ('and', 1),
#  ('USB-C', 1),
#  ('wall', 1),
#  ('charger', 1),
#  ('respectively', 1),
#  ("Hyper's", 1),
#  ('sale', 1),
#  ('will', 1),
#  ('end', 1),
#  ('later', 1),
#  ('today', 1),
#  ('while', 1),
#  ("Satechi's", 1),
#  ('will', 1),
#  ('run', 1),
#  ('for', 1),
#  ('one', 1),
#  ('week', 1),
#  ('through', 1),
#  ('October', 1),
#  ('7', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('"', 1),
#  ("'Read", 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('12', 1),
#  ("comments'", 1),
#  ("''", 1),
#  ('"Deals:', 1),
#  ('AT', 1),
#  ('T', 1),
#  ('Taking', 1),
#  ('15', 1),
#  ('Off', 1),
#  ("Apple's", 1),
#  ('MagSafe', 1),
#  ('Accessories"', 1),
#  ("'Wednesday", 1),
#  ('September', 1),
#  ('29', 1),
#  ('2021', 1),
#  ('7:58', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ("Broussard'", 1),
#  ('"Today', 1),
#  ('at', 1),
#  ('AT', 1),
#  ('T', 1),
#  ('you', 1),
#  ('can', 1),
#  ('get', 1),
#  ('15', 1),
#  ('percent', 1),
#  ('off', 1),
#  ('a', 1),
#  ('wide', 1),
#  ('selection', 1),
#  ('of', 1),
#  ("Apple's", 1),
#  ('MagSafe', 1),
#  ('accessories', 1),
#  ('including', 1),
#  ('Clear', 1),
#  ('Silicone', 1),
#  ('and', 1),
#  ('Leather', 1),
#  ('Cases', 1),
#  ('for', 1),
#  ('the', 1),
#  ('iPhone', 1),
#  ('13', 1),
#  ('13', 1),
#  ('mini', 1),
#  ('13', 1),
#  ('Pro', 1),
#  ('and', 1),
#  ('13', 1),
#  ('Pro', 1),
#  ('Max', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('payment', 1),
#  ('which', 1),
#  ('helps', 1),
#  ('us', 1),
#  ('keep', 1),
#  ('the', 1),
#  ('site', 1),
#  ('running', 1),
#  ('Sale', 1),
#  ('prices', 1),
#  ('have', 1),
#  ('been', 1),
#  ('"', 1),
#  ("'Read", 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('13', 1),
#  ("comments'", 1),
#  ("''", 1),
#  ('"Deals:', 1),
#  ('Get', 1),
#  ("Apple's", 1),
#  ('256GB', 1),
#  ('Wi-Fi', 1),
#  ('iPad', 1),
#  ('Air', 1),
#  ('for', 1),
#  ('649', 1),
#  ('99', 1),
#  ('99', 1),
#  ('Off', 1),
#  ('"', 1),
#  ("'Tuesday", 1),
#  ('September', 1),
#  ('28', 1),
#  ('2021', 1),
#  ('10:05', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ("Broussard'", 1),
#  ("'Amazon", 1),
#  ('today', 1),
#  ('has', 1),
#  ('the', 1),
#  ('256GB', 1),
#  ('iPad', 1),
#  ('Air', 1),
#  ('for', 1),
#  ('649', 1),
#  ('99', 1),
#  ('down', 1),
#  ('from', 1),
#  ('749', 1),
#  ('00', 1),
#  ('This', 1),
#  ('sale', 1),
#  ('price', 1),
#  ('is', 1),
#  ('available', 1),
#  ('in', 1),
#  ('Rose', 1),
#  ('Gold', 1),
#  ('Silver', 1),
#  ('Sky', 1),
#  ('Blue', 1),
#  ('and', 1),
#  ('Space', 1),
#  ('Gray', 1),
#  ('but', 1),
#  ('only', 1),
#  ('Rose', 1),
#  ('Gold', 1),
#  ('is', 1),
#  ('available', 1),
#  ('to', 1),
#  ('ship', 1),
#  ('out', 1),
#  ('today', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('and', 1),
#  ('make', 1),
#  ('a', 1),
#  ('purchase', 1),
#  ('we', 1),
#  ('may', 1),
#  ('receive', 1),
#  ('a', 1),
#  ('small', 1),
#  ('payment', 1),
#  ('which', 1),
#  ('helps', 1),
#  ('us', 1),
#  ('keep', 1),
#  ('the', 1),
#  ('site', 1),
#  ('running', 1),
#  ('This', 1),
#  ('same', 1),
#  ('sale', 1),
#  ("'", 1),
#  ("'Read", 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('3', 1),
#  ("comments'", 1),
#  ("''", 1),
#  ("'Deals:", 1),
#  ('Verizon', 1),
#  ('Offering', 1),
#  ('Up', 1),
#  ('to', 1),
#  ('30', 1),
#  ('Off', 1),
#  ('MagSafe', 1),
#  ('Accessory', 1),
#  ('Bundles', 1),
#  ('iPhone', 1),
#  ('13', 1),
#  ('Cases', 1),
#  ('and', 1),
#  ("More'", 1),
#  ("'Monday", 1),
#  ('September', 1),
#  ('27', 1),
#  ('2021', 1),
#  ('11:53', 1),
#  ('am', 1),
#  ('PDT', 1),
#  ('by', 1),
#  ('Mitchel', 1),
#  ("Broussard'", 1),
#  ('"Today', 1),
#  ("we're", 1),
#  ('tracking', 1),
#  ('a', 1),
#  ('handful', 1),
#  ('of', 1),
#  ('solid', 1),
#  ('accessory', 1),
#  ('discounts', 1),
#  ('offered', 1),
#  ('by', 1),
#  ('Verizon', 1),
#  ('offering', 1),
#  ('a', 1),
#  ('chance', 1),
#  ('to', 1),
#  ('save', 1),
#  ('on', 1),
#  ('a', 1),
#  ('new', 1),
#  ('case', 1),
#  ('or', 1),
#  ('screen', 1),
#  ('protector', 1),
#  ('for', 1),
#  ('your', 1),
#  ('iPhone', 1),
#  ('13', 1),
#  ('MagSafe', 1),
#  ('bundles', 1),
#  ('and', 1),
#  ('more', 1),
#  ('Verizon', 1),
#  ('offers', 1),
#  ('free', 1),
#  ('two', 1),
#  ('day', 1),
#  ('shipping', 1),
#  ('across', 1),
#  ('the', 1),
#  ('board', 1),
#  ('on', 1),
#  ('orders', 1),
#  ('over', 1),
#  ('49', 1),
#  ('even', 1),
#  ('if', 1),
#  ('you', 1),
#  ("don't", 1),
#  ('use', 1),
#  ('Verizon', 1),
#  ('as', 1),
#  ('a', 1),
#  ('carrier', 1),
#  ('Note:', 1),
#  ('MacRumors', 1),
#  ('is', 1),
#  ('an', 1),
#  ('affiliate', 1),
#  ('partner', 1),
#  ('with', 1),
#  ('some', 1),
#  ('of', 1),
#  ('these', 1),
#  ('vendors', 1),
#  ('When', 1),
#  ('you', 1),
#  ('click', 1),
#  ('a', 1),
#  ('link', 1),
#  ('"', 1),
#  ("'Read", 1),
#  ('Full', 1),
#  ('Article', 1),
#  ('10', 1),
#  ("comments'", 1),
#  ("''", 1),
#  ('"Deals:', 1),
#  ('Get', 1),
#  ('Up', 1),
#  ('to', 1),
#  ('45', 1),
#  ('Off', 1),
#  ("Anker's", 1),
#  ('USB-C', 1),
#  ('Chargers', 1),
#  ('MagSafe-Compatible', 1),
#  ('Accessories', 1),
#  ('and', 1),
#  ('More"', 1),
#  ("'Monday", 1),
#  ('September', 1),
#  ('27', 1),
#  ...]

# %%
word_counts = {}
for word in words:
    word = word.lower()
    word_counts[word] = word_counts.get(word, 0) + 1

print(f'Total number of words:  {sum(word_counts.values())}')
# Out:
# Total number of words:  1936

# %%
print('\n\nList of Words: ')
print('\n\nWord \t\tFrequency ')
for key, values in word_counts.items():
    if key == '':   continue
    print(f' {key}: \t {values} ')
# Out:
# List of Words:
#
#
# Word 		Frequency
#  '': 	 19
#  'forums': 	 1
#  'search: 	 1
#  site: 	 8
#  ': 	 11
#  'apple: 	 2
#  vision: 	 1
#  proios: 	 1
#  17iphone: 	 1
#  15iphone: 	 1
#  15: 	 8
#  proiphone: 	 1
#  16iphone: 	 1
#  16: 	 1
#  promacos: 	 1
#  sonomavisionoswatchos: 	 1
#  10macbook: 	 1
#  pro: 	 10
#  14: 	 1
#  16"homepodiphone: 	 1
#  14apple: 	 1
#  tvipad: 	 1
#  proapple: 	 2
#  watch: 	 3
#  ultra: 	 1
#  2ipadairpods: 	 1
#  3apple: 	 1
#  carapple: 	 1
#  display: 	 1
#  xdrhomepod: 	 1
#  minimac: 	 1
#  promacbook: 	 1
#  airiphone: 	 1
#  13airpods: 	 1
#  maxairpods: 	 1
#  dealsapple: 	 1
#  studio: 	 1
#  displayapple: 	 1
#  semac: 	 2
#  studioimacipad: 	 1
#  airipad: 	 1
#  miniiphone: 	 1
#  miniios: 	 1
#  18apple: 	 1
#  series: 	 1
#  9carplayipados: 	 1
#  17apple: 	 1
#  pay': 	 1
#  'all: 	 1
#  'macrumors: 	 1
#  iphone: 	 20
#  and: 	 53
#  ipad: 	 11
#  blog:: 	 1
#  apps: 	 1
#  news: 	 2
#  rumors': 	 2
#  'deals:: 	 8
#  adorama: 	 2
#  introduces: 	 2
#  new: 	 15
#  low: 	 3
#  prices: 	 6
#  on: 	 24
#  32gb: 	 2
#  apple: 	 8
#  tv: 	 4
#  4k: 	 4
#  159: 	 2
#  airpods: 	 8
#  max: 	 4
#  449: 	 1
#  'tuesday: 	 3
#  october: 	 5
#  5: 	 1
#  2021: 	 20
#  7:27: 	 1
#  am: 	 17
#  pdt: 	 18
#  by: 	 19
#  mitchel: 	 18
#  broussard': 	 18
#  'adorama: 	 1
#  today: 	 14
#  has: 	 8
#  a: 	 67
#  collection: 	 2
#  of: 	 32
#  deals: 	 5
#  select: 	 3
#  products: 	 1
#  including: 	 2
#  the: 	 45
#  m1: 	 1
#  macbook: 	 1
#  note:: 	 18
#  macrumors: 	 18
#  is: 	 27
#  an: 	 19
#  affiliate: 	 18
#  partner: 	 18
#  with: 	 24
#  when: 	 19
#  you: 	 27
#  click: 	 16
#  link: 	 16
#  make: 	 15
#  purchase: 	 16
#  we: 	 16
#  may: 	 13
#  receive: 	 12
#  small: 	 12
#  payment: 	 11
#  which: 	 11
#  helps: 	 9
#  us: 	 9
#  keep: 	 9
#  running: 	 5
#  can: 	 7
#  get: 	 12
#  for: 	 22
#  00: 	 11
#  down: 	 7
#  from: 	 10
#  179: 	 1
#  this: 	 12
#  all-time: 	 3
#  'read: 	 18
#  full: 	 18
#  article: 	 19
#  11: 	 3
#  comments': 	 18
#  10: 	 4
#  amazon: 	 16
#  credit: 	 2
#  purchasing: 	 1
#  100: 	 4
#  gift: 	 3
#  card': 	 1
#  'monday: 	 6
#  4: 	 2
#  8:52: 	 1
#  'amazon: 	 2
#  offering: 	 4
#  in: 	 11
#  spend: 	 1
#  or: 	 3
#  more: 	 4
#  card: 	 3
#  digital: 	 1
#  will: 	 4
#  be: 	 2
#  delivered: 	 1
#  to: 	 19
#  via: 	 1
#  email: 	 1
#  offer: 	 1
#  automatically: 	 1
#  applied: 	 1
#  at: 	 17
#  checkout: 	 1
#  screen: 	 2
#  some: 	 11
#  these: 	 16
#  vendors: 	 12
#  44: 	 1
#  sales: 	 3
#  hit: 	 2
#  every: 	 2
#  model: 	 4
#  starting: 	 4
#  109: 	 1
#  regular: 	 1
#  airpods': 	 1
#  7:49: 	 1
#  "today: 	 4
#  we're: 	 3
#  tracking: 	 3
#  apple's: 	 10
#  return: 	 1
#  lowest-ever: 	 1
#  price: 	 4
#  wireless: 	 3
#  charging: 	 3
#  case: 	 3
#  priced: 	 2
#  129: 	 1
#  199: 	 1
#  below: 	 1
#  you'll: 	 4
#  also: 	 1
#  find: 	 3
#  wired: 	 1
#  ": 	 15
#  13: 	 15
#  take: 	 2
#  up: 	 8
#  off: 	 17
#  tablets: 	 2
#  amazon': 	 1
#  'friday: 	 2
#  1: 	 1
#  7:28: 	 1
#  "amazon: 	 2
#  few: 	 1
#  both: 	 2
#  11-inch: 	 1
#  12: 	 12
#  9-inch: 	 3
#  configurations: 	 1
#  have: 	 3
#  chance: 	 2
#  save: 	 4
#  models: 	 2
#  sale: 	 9
#  focuses: 	 1
#  wi-fi: 	 6
#  only: 	 4
#  they're: 	 1
#  all: 	 2
#  available: 	 5
#  2: 	 1
#  "deals:: 	 9
#  magsafe: 	 10
#  battery: 	 5
#  pack: 	 3
#  drops: 	 2
#  84: 	 2
#  'thursday: 	 4
#  september: 	 14
#  30: 	 6
#  11:22: 	 1
#  "yesterday: 	 1
#  shared: 	 1
#  discount: 	 4
#  event: 	 1
#  happening: 	 1
#  t: 	 3
#  where: 	 1
#  percent: 	 5
#  accessories: 	 7
#  fall: 	 1
#  one: 	 4
#  notable: 	 3
#  accessory: 	 4
#  was: 	 2
#  but: 	 2
#  it: 	 1
#  out: 	 2
#  stock: 	 1
#  however: 	 1
#  that's: 	 1
#  changed: 	 1
#  now: 	 2
#  order: 	 3
#  99: 	 8
#  19: 	 1
#  20: 	 7
#  hyper's: 	 2
#  18w: 	 1
#  packs: 	 1
#  satechi's: 	 4
#  100w: 	 1
#  usb-c: 	 5
#  wall: 	 4
#  charger": 	 1
#  8:18: 	 2
#  pair: 	 2
#  charging-related: 	 1
#  hyper: 	 1
#  satechi: 	 2
#  are: 	 5
#  portable: 	 3
#  charger: 	 4
#  respectively: 	 2
#  end: 	 1
#  later: 	 1
#  while: 	 1
#  run: 	 1
#  week: 	 5
#  through: 	 1
#  7: 	 1
#  taking: 	 2
#  accessories": 	 1
#  'wednesday: 	 3
#  29: 	 1
#  7:58: 	 1
#  wide: 	 1
#  selection: 	 1
#  clear: 	 2
#  silicone: 	 2
#  leather: 	 2
#  cases: 	 4
#  mini: 	 4
#  been: 	 1
#  256gb: 	 2
#  air: 	 2
#  649: 	 2
#  28: 	 1
#  10:05: 	 1
#  749: 	 1
#  rose: 	 2
#  gold: 	 3
#  silver: 	 1
#  sky: 	 1
#  blue: 	 1
#  space: 	 2
#  gray: 	 2
#  ship: 	 1
#  same: 	 1
#  3: 	 1
#  verizon: 	 5
#  bundles: 	 2
#  more': 	 1
#  27: 	 2
#  11:53: 	 1
#  handful: 	 1
#  solid: 	 2
#  discounts: 	 3
#  offered: 	 1
#  protector: 	 1
#  your: 	 5
#  offers: 	 1
#  free: 	 2
#  two: 	 2
#  day: 	 3
#  shipping: 	 1
#  across: 	 1
#  board: 	 1
#  orders: 	 1
#  over: 	 1
#  49: 	 1
#  even: 	 1
#  if: 	 1
#  don't: 	 1
#  use: 	 1
#  as: 	 3
#  carrier: 	 1
#  45: 	 2
#  anker's: 	 2
#  chargers: 	 5
#  magsafe-compatible: 	 4
#  more": 	 1
#  8:39: 	 1
#  'anker: 	 1
#  introduced: 	 2
#  box: 	 1
#  time: 	 3
#  around: 	 1
#  include: 	 1
#  savings: 	 1
#  batteries: 	 1
#  200: 	 1
#  virtual: 	 1
#  homepod: 	 1
#  visible': 	 1
#  24: 	 2
#  7:19: 	 1
#  "it's: 	 1
#  launch: 	 2
#  anyone: 	 1
#  who: 	 1
#  hasn't: 	 1
#  pre-ordered: 	 1
#  smartphone: 	 1
#  still: 	 2
#  plenty: 	 1
#  options: 	 1
#  highlighting: 	 1
#  deal: 	 1
#  verizon-owned: 	 1
#  visible: 	 1
#  low-cost: 	 1
#  alternative: 	 1
#  big: 	 1
#  name: 	 1
#  carriers: 	 1
#  64gb: 	 4
#  299: 	 2
#  first: 	 5
#  23: 	 2
#  9:09: 	 1
#  'the: 	 1
#  arrived: 	 1
#  2-inch: 	 1
#  329: 	 1
#  bundle: 	 2
#  dual: 	 1
#  car: 	 4
#  chargers": 	 1
#  7:00: 	 1
#  "satechi: 	 1
#  announced: 	 1
#  release: 	 1
#  trio: 	 1
#  aimed: 	 1
#  devices: 	 3
#  website: 	 1
#  them: 	 2
#  35: 	 1
#  record-low: 	 1
#  latest: 	 1
#  magic: 	 2
#  keyboard: 	 2
#  324: 	 2
#  88: 	 2
#  black": 	 1
#  22: 	 3
#  1:15: 	 1
#  pm: 	 1
#  its: 	 3
#  best: 	 2
#  black: 	 2
#  white: 	 1
#  colors: 	 2
#  349: 	 1
#  13": 	 1
#  8:25: 	 1
#  "a: 	 1
#  duo: 	 1
#  live: 	 1
#  began: 	 1
#  ago: 	 1
#  it's: 	 1
#  great: 	 1
#  buy: 	 1
#  ahead: 	 1
#  friday: 	 1
#  17: 	 3
#  not: 	 1
#  upgrading: 	 1
#  official: 	 1
#  off": 	 1
#  21: 	 1
#  "now: 	 1
#  that: 	 2
#  family: 	 1
#  launching: 	 1
#  previous: 	 1
#  generation: 	 1
#  seeing: 	 1
#  6: 	 2
#  tablet: 	 2
#  459: 	 2
#  39: 	 1
#  8:04: 	 1
#  "following: 	 1
#  footsteps: 	 1
#  expercom: 	 1
#  walmart: 	 1
#  last: 	 1
#  ever: 	 1
#  except: 	 1
#  purple: 	 1
#  499: 	 1
#  'exclusive: 	 1
#  deals:: 	 1
#  40: 	 1
#  mount: 	 2
#  our: 	 3
#  anker: 	 3
#  sale': 	 1
#  7:43: 	 1
#  "we've: 	 1
#  partnered: 	 1
#  again: 	 1
#  bring: 	 1
#  readers: 	 1
#  coupon: 	 1
#  codes: 	 1
#  introduce: 	 1
#  earbuds: 	 1
#  highlight: 	 1
#  markdown: 	 1
#  magnetic: 	 1
#  exclusive: 	 1
#  code: 	 1
#  'newer: 	 1
#  posts': 	 2
#  'archives': 	 1
#  'older: 	 1
#  'guides': 	 1
#  'ios: 	 1
